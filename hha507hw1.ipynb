# %% [markdown]
# <a href="https://colab.research.google.com/github/chebbin/datasci_1_loading/blob/main/hha507hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # CSV datasets

# %% [markdown]
# ## CSV dataset 1
#
# ### The Comprehensive Care for Joint Replacement Model: Metropolitan Statistical Areas (MSAs) dataset presents MSAs that are participating in the CMS Innovation Center Comprehensive Care for Joint Replacement Model, a model to support better and more efficient care for beneficiaries undergoing the most common inpatient surgery for Medicare beneficiaries: hip and knee replacements. Participation in this model is designated by geographic area, specifically MSAs. The information contained in the dataset can include MSA identification number, MSA geographic name and associated county or counties.

# %%
#### CSV dataset 1
joint_replacement_df = pd.read_csv('/content/joint_replacement.csv')
joint_replacement_df
# Out:
#       MSA                                       MSA Title  \
# 0   14500                                     Boulder, CO
# 1   16180                                 Carson City, NV
# 2   17860                                    Columbia, MO
# 3   19500                                     Decatur, IL
# 4   22420                                       Flint, MI
# ..    ...                                             ...
# 62  34980  Nashville-Davidson--Murfreesboro--Franklin, TN
# 63  41180                                St. Louis, MO-IL
# 64  48620                                     Wichita, KS
# 65  42660                     Seattle-Tacoma-Bellevue, WA
# 66  22500                                    Florence, SC
#
#                                              Counties
# 0                                      Boulder County
# 1                                         Carson City
# 2                                        Boone County
# 3                                        Macon County
# 4                                      Genesee County
# ..                                                ...
# 62  Cannon County, Cheatham County, Davidson Count...
# 63  Bond County, Calhoun County, Clinton County, J...
# 64  Butler County, Harvey County, Kingman County, ...
# 65       King County, Snohomish County, Pierce County
# 66                 Darlington County, Florence County
#
# [67 rows x 3 columns]

# %%
#### Columns of this data
joint_replacement_df.columns
# Out:
# Index(['MSA', 'MSA Title', 'Counties'], dtype='object')

# %% [markdown]
# ## CSV dataset 2
#
# ### Access-related bloodstream infections at dialysis centers

# %%
#### CSV dataset 2
access_infections_dialysis_df = pd.read_csv('/content/2015_Dialysis_AR_BSI_TABLE.csv')
access_infections_dialysis_df
# Out:
#                        Facility Name               Access Type  AR-BSI Count  \
# 0        NOBLE WOODS DIALYSIS CLINIC              Other Access             0
# 1                        FMC REDMOND              Other Access             0
# 2    PNRS EMANUEL PEDIATRIC DIALYSIS                     Graft             0
# 3    NORTHEAST PORTLAND RENAL CENTER                     Graft             0
# 4    PNRS/THC RAINES DIALYSIS CENTER                   Fistula             0
# ..                               ...                       ...           ...
# 415    USRC PORTLAND DIALYSIS CENTER                       All             7
# 416   PNRS MCMINNVILLE KIDNEY CENTER              Other Access             0
# 417                     FMC COOS BAY     Tunneled Central Line             3
# 418    MERIDIAN PARK DIALYSIS CENTER                   Fistula             0
# 419             OREGON KIDNEY CENTER  Nontunneled Central Line             0
#
#      Patient Months  AR-BSI/100 Pt. Months  National AR-BSI Mean  \
# 0                 6                   0.00                   NaN
# 1                 0                    NaN                   NaN
# 2                 0                    NaN                  0.51
# 3               265                   0.00                  0.51
# 4               370                   0.00                  0.23
# ..              ...                    ...                   ...
# 415             772                   0.91                  0.88
# 416               0                    NaN                   NaN
# 417             291                   1.03                  2.55
# 418             365                   0.00                  0.23
# 419               3                   0.00                  2.18
#
#     Comparison Interpretation  Percentile on National Distribution  \
# 0                         NaN                                  NaN
# 1                         NaN                                  NaN
# 2                         NaN                                  NaN
# 3    Better: fewer infections                                 50.0
# 4    Better: fewer infections                                 50.0
# ..                        ...                                  ...
# 415    Worse: more infections                                  NaN
# 416                       NaN                                  NaN
# 417  Better: fewer infections                                 38.0
# 418  Better: fewer infections                                 50.0
# 419  Better: fewer infections                                  NaN
#
#          County HPPRegion                                         Location 1  \
# 0    WASHINGTON   Region1                   5333 W BASELINE\nHILLSBORO 97123
# 1     DESCHUTES   Region7  916 SW 17TH STREET, SUITE 100\nREDMOND 97756\n...
# 2         UNION   Region9  10601 WALTON RD\nLA GRANDE 97850\n(45.337025, ...
# 3     MULTNOMAH   Region1  703 NE HANCOCK STREET\nPORTLAND 97212\n(45.536...
# 4    WASHINGTON   Region1  1809 MAPLE STREET\nFOREST GROVE 97116\n(45.517...
# ..          ...       ...                                                ...
# 415   MULTNOMAH   Region1  10595 SE STARK STREET\nPORTLAND 97216\n(45.519...
# 416   MULTNOMAH   Region1  2824 NE WASCO STREET, SUITE 100\nPORTLAND 9723...
# 417        COOS   Region3  1971 THOMPSON ROAD\nCOOS 97420\n(43.386065, -1...
# 418  WASHINGTON   Region1  19255 SW 65TH AVENUE, SUITE 100\nTUALATIN 9706...
# 419   MULTNOMAH   Region1  5318 NE IRVING STREET\nPORTLAND 97213\n(45.528...
#
#                                               SIR Icon
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    https://data.oregon.gov/views/4wzc-acdn/files/...
# 4    https://data.oregon.gov/views/4wzc-acdn/files/...
# ..                                                 ...
# 415  https://data.oregon.gov/views/4wzc-acdn/files/...
# 416                                                NaN
# 417  https://data.oregon.gov/views/4wzc-acdn/files/...
# 418  https://data.oregon.gov/views/4wzc-acdn/files/...
# 419  https://data.oregon.gov/views/4wzc-acdn/files/...
#
# [420 rows x 12 columns]

# %%
#### columns of this data
access_infections_dialysis_df.columns
# Out:
# Index(['Facility Name', 'Access Type', 'AR-BSI Count', 'Patient Months',
#        'AR-BSI/100 Pt. Months', 'National AR-BSI Mean',
#        'Comparison Interpretation', 'Percentile on National Distribution',
#        'County', 'HPPRegion', 'Location 1', 'SIR Icon'],
#       dtype='object')

# %% [markdown]
# # JSON datasets

# %% [markdown]
# ## JSON dataset 1
#
# ### This dataset represents hospital-reported data for all pediatric patients with a diagnosis of severe sepsis or septic shock seen at New York State Article 28 (acute care) facilities and reported to the New York State Department of Health. Quality measures are calculated using this data for reporting hospital- specific rates and trends. These measures, reported as statewide and hospital-specific rates, reflect several key processes of care that can increase the probability of surviving an episode of sepsis.

# %%
data_url = ('https://health.data.ny.gov/api/views/4t82-a928/columns.json')
pediatric_sepsis_df = pd.read_json(data_url)
pediatric_sepsis_df
# Out:
#           id                                        name dataTypeName  \
# 0  414009086                              Discharge Year         text
# 1  414009085                                         PFI         text
# 2  414009092                               Facility Name         text
# 3  414009091                     Data Dictionary Version         text
# 4  414009090               Timely Antibiotic Denominator       number
# 5  414009093                      Timely Antibiotics (%)       number
# 6  414009089  Timely Antibiotics Quintile of Performance         text
# 7  414009088                   1-Hour Bundle Denominator       number
# 8  414009084                       Met 1-Hour Bundle (%)       number
# 9  414009087       1-Hour Bundle Quintile of Performance         text
#
#                                          description  \
# 0  The year of the severe sepsis or septic shock ...
# 1  The facility’s Permanent Facility Identifier (...
# 2  The name of the hospital in which the discharg...
# 3  Version of the data dictionary that was used f...
# 4  The total number of sepsis cases eligible for ...
# 5  The percentage of eligible sepsis cases for wh...
# 6  The quintile of hospital performance relative ...
# 7  The total number of sepsis cases eligible for ...
# 8  The percentage of eligible cases for whom the ...
# 9  The quintile of hospital performance relative ...
#
#                        fieldName  position renderTypeName  tableColumnId  \
# 0                 discharge_year         1           text       82858133
# 1                            pfi         2           text       82858132
# 2                  facility_name         3           text       82858139
# 3        data_dictionary_version         4           text       82858138
# 4  timely_antibiotic_denominator         5         number       82858137
# 5             timely_antibiotics         6         number       82858140
# 6    timely_antibiotics_quintile         7           text       82858136
# 7     _1_hour_bundle_denominator         8         number       82858135
# 8              met_1_hour_bundle         9         number       82858131
# 9     _1_hour_bundle_quintile_of        10           text       82858134
#
#                                       cachedContents              format
# 0  {'largest': '2017', 'non_null': '13', 'null': ...                  {}
# 1  {'largest': '003376', 'non_null': '13', 'null'...                  {}
# 2  {'largest': 'Women And Childrens Hospital Of B...                  {}
# 3  {'largest': 'v4.1', 'non_null': '13', 'null': ...                  {}
# 4  {'largest': '71', 'non_null': '13', 'null': '0...                  {}
# 5  {'largest': '100.00', 'non_null': '13', 'null'...  {'precision': '2'}
# 6  {'largest': '5-Highest', 'non_null': '13', 'nu...                  {}
# 7  {'largest': '71', 'non_null': '13', 'null': '0...                  {}
# 8  {'largest': '64.30', 'non_null': '13', 'null':...  {'precision': '2'}
# 9  {'largest': '5-Highest', 'non_null': '13', 'nu...                  {}

# %%
#### columns of this data
pediatric_sepsis_df.columns
# Out:
# Index(['id', 'name', 'dataTypeName', 'description', 'fieldName', 'position',
#        'renderTypeName', 'tableColumnId', 'cachedContents', 'format'],
#       dtype='object')

# %% [markdown]
# ## JSON dataset 2
#
# This dataset contains the number of cases, number of in hospital/30 day deaths, observed, expected and risk- adjusted mortality rates for Percutaneous Coronary Interventions (PCI) by cardiologist. Physician information is presented for each physician who a) performed 200 or more procedures during the three year analysis and/or b) performed at least one PCI in each of the three years. The results for physicians not meeting the above criteria are grouped together and reported as “All others” in the hospital in which the procedures are performed. Regions represent where the hospitals are located. The initial Health Data NY dataset includes patients discharged between January 1, 2008, and December 31, 2010. Analyses of risk-adjusted mortality rates and associated risk factors are provided for the three-year period from 2008 through 2010. Analyses of all cases and non-emergency cases (which represent the majority of procedures) are included.

# %%
data_url = ('https://health.data.ny.gov/api/views/ekig-i57g/columns.json')
mortality_percutaneous_coronary_interventions_df = pd.read_json(data_url)
mortality_percutaneous_coronary_interventions_df
# Out:
#            id                                name dataTypeName  \
# 0   576748303                      Physician Name         text
# 1   576748304        NYS Physician License Number         text
# 2   576748319                National Provider ID         text
# 3   576748305                         Facility ID         text
# 4   576748306                       Hospital Name         text
# 5   576748307                     Detailed Region         text
# 6   576748308                              Region         text
# 7   576748309                           Procedure         text
# 8   576748310          Year of Hospital Discharge         text
# 9   576748311                     Number of Cases       number
# 10  576748312                    Number of Deaths       number
# 11  576748313             Observed Mortality Rate       number
# 12  576748314             Expected Mortality Rate       number
# 13  576748315        Risk-Adjusted Mortality Rate       number
# 14  576748316  Lower Limit of Confidence Interval       number
# 15  576748317  Upper Limit of Confidence Interval       number
# 16  576748318                  Comparison Results         text
#
#                                           description  \
# 0   Name of the physician that performed the proce...
# 1   New York State (NYS) License Number of the phy...
# 2   National Provider Identifier of the physician ...
# 3   New York State (NYS) Facility Identification N...
# 4                                       Hospital Name
# 5   New York State (NYS) License Number of the phy...
# 6         Region of hospital performing the procedure
# 7   Type of procedure performed:  All PCI, Non-Eme...
# 8         Year or range of years included in analysis
# 9                      Number of procedures performed
# 10  Number of cases resulting in death during the ...
# 11  The observed number of deaths divided by the t...
# 12  The sum of the predicted probabilities of deat...
# 13  The best estimate, based on the statistical mo...
# 14  Lower 95% confidence limit for risk adjusted m...
# 15  Upper 95% confidence limit for risk adjusted m...
# 16  A statistical test was performed to determine ...
#
#                              fieldName  position renderTypeName  \
# 0                       physician_name         1           text
# 1         nys_physician_license_number         2           text
# 2                 national_provider_id         3           text
# 3                          facility_id         4           text
# 4                        hospital_name         5           text
# 5                      detailed_region         6           text
# 6                               region         7           text
# 7                            procedure         8           text
# 8           year_of_hospital_discharge         9           text
# 9                      number_of_cases        10         number
# 10                    number_of_deaths        11         number
# 11             observed_mortality_rate        12         number
# 12             expected_mortality_rate        13         number
# 13        risk_adjusted_mortality_rate        14         number
# 14  lower_limit_of_confidence_interval        15         number
# 15  upper_limit_of_confidence_interval        16         number
# 16                  comparison_results        17           text
#
#     tableColumnId  width                                     cachedContents  \
# 0        10591450    116  {'non_null': '20531', 'largest': 'Zlotnick D',...
# 1        10591451    203  {'non_null': '20525', 'largest': '290772', 'nu...
# 2       147152356    158  {'non_null': '4491', 'largest': '1992961460', ...
# 3        10591448     77  {'non_null': '20547', 'largest': '3058', 'null...
# 4        10591449    197  {'non_null': '20529', 'largest': 'Winthrop-Uni...
# 5        10591452    177  {'non_null': '20547', 'largest': 'Western NY -...
# 6        10591453    172  {'non_null': '20547', 'largest': 'Western NY -...
# 7        10591454    121  {'non_null': '20535', 'largest': 'Non-Emergenc...
# 8        10591455    172  {'non_null': '20547', 'largest': '2017-2019', ...
# 9        10591456    119  {'non_null': '20547', 'largest': '162918', 'nu...
# 10       10591457    128  {'non_null': '20541', 'largest': '1916', 'null...
# 11       10591458    156  {'non_null': '20541', 'largest': '100', 'null'...
# 12       10591459    160  {'non_null': '20541', 'largest': '25.85', 'nul...
# 13       10591460    184  {'non_null': '20541', 'largest': '100.00', 'nu...
# 14       10591461    209  {'non_null': '20521', 'largest': '2.15', 'null...
# 15       10591462    224  {'non_null': '20521', 'largest': '100', 'null'...
# 16       10591463    274  {'non_null': '20547', 'largest': 'Statewide Ra...
#
#                                                format
# 0                                   {'align': 'left'}
# 1                                   {'align': 'left'}
# 2                                                  {}
# 3                                   {'align': 'left'}
# 4                                   {'align': 'left'}
# 5                                   {'align': 'left'}
# 6                                   {'align': 'left'}
# 7                                   {'align': 'left'}
# 8                                   {'align': 'left'}
# 9   {'precisionStyle': 'standard', 'noCommas': 'fa...
# 10  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 11  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 12  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 13  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 14  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 15  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 16                                  {'align': 'left'}

# %%
#### columns of this data
mortality_percutaneous_coronary_interventions_df.columns
# Out:
# Index(['id', 'name', 'dataTypeName', 'description', 'fieldName', 'position',
#        'renderTypeName', 'tableColumnId', 'width', 'cachedContents', 'format'],
#       dtype='object')

# %% [markdown]
# ## JSON dataset 3

# %% [markdown]
# # XLSX datasets

# %% [markdown]
# ## XLSX dataset 1
#
# ### This dataset provides data for new prescription drugs introduced to market in California with a Wholesale Acquisition Cost (WAC) that exceeds the Medicare Part D specialty drug cost threshold. Prescription drug manufacturers submit information to HCAI within a specified time period after a drug is introduced to market. Key data elements include the National Drug Code (NDC) administered by the FDA, a narrative description of marketing and pricing plans, and WAC, among other information.

# %%
#### XLSX dataset 1

new_drugs_df = pd.read_excel('/content/new-drug-report-q1-q4-2022.xlsx')
new_drugs_df
# Out:
#                     Manufacturer Name   NDC Number  \
# 0               Aadi Bioscience, Inc.  80803015350
# 1                              AbbVie     74231030
# 2                              AbbVie     74104328
# 3                              AbbVie     74501501
# 4                              AbbVie     74107001
# ..                                ...          ...
# 342  Zydus Pharmaceuticals (USA) Inc.  70710103207
# 343  Zydus Pharmaceuticals (USA) Inc.  70710103308
# 344  Zydus Pharmaceuticals (USA) Inc.  70710103508
# 345  Zydus Pharmaceuticals (USA) Inc.  70710103107
# 346  Zydus Pharmaceuticals (USA) Inc.  68382091206
#
#                               Drug Product Description  \
# 0    FYARRO™ (sirolimus protein-bound particles for...
# 1             RINVOQ (upadacitinib) 30MG 30 Day Bottle
# 2             RINVOQ (upadacitinib) 45MG 30 Day Bottle
# 3                               RISA 600mg / 10mL VIAL
# 4                          SKYRIZI (risankizumab-rzaa)
# ..                                                 ...
# 342                Lenalidomide 10mg Capsule (28 CAPS)
# 343                Lenalidomide 15mg Capsule (21 CAPS)
# 344                Lenalidomide 25mg Capsule (21 CAPS)
# 345                 Lenalidomide 5mg Capsule (28 CAPS)
# 346                 Fingolimod 0.5mg Capsule (30 Caps)
#
#     Date Introduced to Market  WAC at Introduction  \
# 0                  2022-02-22              6785.00
# 1                  2022-01-24              5671.26
# 2                  2022-03-23             10586.24
# 3                  2022-06-28              9136.40
# 4                  2022-08-23             18272.79
# ..                        ...                  ...
# 342                2022-09-14             20157.36
# 343                2022-09-14             15118.04
# 344                2022-09-14             15118.04
# 345                2022-09-14             20157.36
# 346                2022-10-20              2220.97
#
#                     Marketing/Pricing Plan Description  \
# 0                                                  NaN
# 1    RINVOQ is marketed for the treatment of refrac...
# 2    RINVOQ is marketed to treat adults with modera...
# 3    SKYRIZI is marketed for the treatment of moder...
# 4    SKYRIZI is marketed for the treatment of moder...
# ..                                                 ...
# 342                                                NaN
# 343                                                NaN
# 344                                                NaN
# 345                                                NaN
# 346                                                NaN
#
#      Marketing/Pricing Plan Non-Public Indicator  \
# 0                                            1.0
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 342                                          1.0
# 343                                          1.0
# 344                                          1.0
# 345                                          1.0
# 346                                          1.0
#
#      Estimated Number of Patients  Breakthrough Therapy Indicator  \
# 0                           300.0                             1.0
# 1                         12000.0                             1.0
# 2                          7200.0                             NaN
# 3                          1000.0                             NaN
# 4                          1000.0                             NaN
# ..                            ...                             ...
# 342                       60000.0                             NaN
# 343                       60000.0                             NaN
# 344                       60000.0                             NaN
# 345                       60000.0                             NaN
# 346                      913925.0                             NaN
#
#      Priority Review Indicator Acquisition Date  Acquisition Price  \
# 0                          1.0              NaN                NaN
# 1                          1.0              NaN                NaN
# 2                          1.0              NaN                NaN
# 3                          1.0              NaN                NaN
# 4                          1.0              NaN                NaN
# ..                         ...              ...                ...
# 342                        NaN              NaN                NaN
# 343                        NaN              NaN                NaN
# 344                        NaN              NaN                NaN
# 345                        NaN              NaN                NaN
# 346                        NaN              NaN                NaN
#
#      Acquisition Price Non-Public Indicator Acquisition Price Comment  \
# 0                                       NaN                       NaN
# 1                                       NaN                       NaN
# 2                                       NaN                       NaN
# 3                                       NaN                       NaN
# 4                                       NaN                       NaN
# ..                                      ...                       ...
# 342                                     NaN                       NaN
# 343                                     NaN                       NaN
# 344                                     NaN                       NaN
# 345                                     NaN                       NaN
# 346                                     NaN                       NaN
#
#                                       General Comments Supporting Documents
# 0    "Aadi has listed Fyarro with a WAC price effec...                  NaN
# 1    Response on estimated volume of patients: RINV...                  NaN
# 2                                                  NaN                  NaN
# 3    Response on estimated volume of patients (1,00...                  NaN
# 4    Response on estimated volume of patients (1,00...                  NaN
# ..                                                 ...                  ...
# 342  This is an AB rated generic product that was d...                  NaN
# 343  This is an AB rated generic product that was d...                  NaN
# 344  This is an AB rated generic product that was d...                  NaN
# 345  This is an AB rated generic product that was d...                  NaN
# 346  This is an AB rated generic product that was d...                  NaN
#
# [347 rows x 16 columns]

# %%
#### columns of this data
new_drugs_df.columns
# Out:
# Index(['Manufacturer Name', 'NDC Number', 'Drug Product Description',
#        'Date Introduced to Market', 'WAC at Introduction',
#        'Marketing/Pricing Plan Description',
#        'Marketing/Pricing Plan Non-Public Indicator',
#        'Estimated Number of Patients', 'Breakthrough Therapy Indicator',
#        'Priority Review Indicator', 'Acquisition Date', 'Acquisition Price',
#        'Acquisition Price Non-Public Indicator', 'Acquisition Price Comment',
#        'General Comments', 'Supporting Documents'],
#       dtype='object')

# %% [markdown]
# ## XLSX dataset 2
#
# ### FDA pet food recalls

# %%
#### XLSX dataset 2

pet_food_recalls_df = pd.read_excel('/content/cvm-recalls.xlsx')
pet_food_recalls_df
# Out:
#           Date                                        Brand-Names  \
# 0   07/29/2021      Triumph, Evolve, Nature Farms, Elm and others
# 1   08/13/2021                                     Simply Nourish
# 2   08/26/2021                           Top Quality Dog Food.com
# 3   10/01/2021                       Fromm Four-Star Nutritionals
# 4   10/12/2021                                       Nutri Source
# 5   12/23/2021                              Woody's Pet Food Deli
# 6   01/04/2022                                         Pure Being
# 7   12/01/2021                             LivaOne and BioLifePet
# 8   10/27/2021                                             Purina
# 9   12/16/2022                                     HEB TEXAS PETS
# 10  12/16/2022                                 Top of the Rockies
# 11  06/18/2022                                           Freshpet
# 12  07/06/2022                              Primal Pet Foods Inc.
# 13  07/12/2022  Beg & Barker, Billo’s Best Friend, and Green C...
# 14  12/02/2022                                             Purina
# 15  02/08/2023                                             Purina
# 16  02/23/2023                                  Bindle Bottle LLC
# 17  03/10/2023                                             Purina
# 18  03/20/2023                                             Kaytee
# 19  05/04/2023                                    Numerous Brands
# 20  02/18/2022                               Numerous brand names
# 21  05/06/2019                                    Southern States
# 22  05/24/2019                                           Norbrook
# 23  06/18/2019                                RXQ Compounding LLC
# 24  03/01/2021                                          Vitakraft
# 25  03/03/2021                                Bravo Packing, Inc.
# 26  03/03/2021                            Ridley Block Operations
# 27  03/16/2021                                Bravo Packing, Inc.
# 28  03/27/2021                                    Multiple brands
# 29  04/12/2021                                          Meow Mix®
# 30  05/20/2021                                    Natural Balance
# 31  06/03/2021  Sportsman’s Pride, Sprout Sporting, Intimidato...
# 32  06/08/2021                                      Hubbard Feeds
# 33  06/11/2021                                             Purina
# 34  06/13/2021                                           Freshpet
# 35  06/29/2021                                        Flock Party
# 36  03/23/2020                                         Icelandic+
# 37  05/08/2020                                   ICU Medical Inc.
# 38  10/30/2019                                  ICU Medical, Inc.
# 39  11/18/2019                                              Quest
# 40  12/30/2020                                           Sportmix
# 41  01/11/2021          Sportmix, Nunn Better, ProPac, and Others
# 42  10/08/2020           Champ, Field Trial, Good Dog, and Others
# 43  03/16/2020                                            Orlando
# 44  01/31/2019                                Hill's Science Diet
# 45  07/26/2019                                             Lennox
# 46  09/12/2019                           KRS Global Biotechnology
# 47  04/24/2019                                              Jurox
# 48  04/29/2019                      Norbrook Laboratories Limited
# 49  08/01/2023                                  Ozona, Go Healthy
# 50  03/26/2018                                    Blue Ridge Beef
# 51  03/02/2018                                    Blue Ridge Beef
# 52  03/02/2018                                 Steve’s Real Foods
# 53  03/20/2018                                            Rad Cat
# 54  03/10/2023                                    Multiple brands
# 55  08/23/2023                               Numerous brand names
# 56  08/25/2023                                             McNess
# 57  09/01/2023                                Merck Animal Health
# 58  09/04/2023                                             Victor
#
#                                   Product-Description  \
# 0                                            Dog Food
# 1                                     Frozen dog food
# 2                                            Beef HVM
# 3                     Shredded Entrée canned dog food
# 4                    Pure Vita Salmon Entrée Dog Food
# 5         Raw Cornish Hen pet food “With Supplements”
# 6                  Advent Calendars for Cats and Dogs
# 7                                          Probiotics
# 8   Supplement feed for cattle livestock and for w...
# 9         HEB TEXAS PETS Indoor Complete Dry Cat Food
# 10                                      Alfalfa Cubes
# 11  Freshpet Select Fresh From the Kitchen Home Co...
# 12    Raw Frozen Primal Patties for Dogs Beef Formula
# 13                                 Chicken dog treats
# 14  Purina Pro Plan Veterinary Diets EN Gastroente...
# 15         Veterinary Diets EL Elemental Dry Dog Food
# 16                                            Bottles
# 17  Pro Plan Veterinary Diets EL Elemental (PPVD E...
# 18                      Wild Bird Food Birders’ Blend
# 19             Various human and animal drug products
# 20  Numerous human food, animal (pet) food, medica...
# 21                                Various animal feed
# 22                Veterinary injectable drug products
# 23  All sterile human and animal products within e...
# 24                           Vita Smart Hedgehog Food
# 25  Ground Beef and Performance Dog, frozen raw pe...
# 26                                CRYSTALYX Sheep-lyx
# 27  Pet food: Performance Dog, beef, green tripe, ...
# 28                                   Dog and Cat Food
# 29             Meow Mix® Original Choice Dry Cat Food
# 30         L.I.D. Green Pea & Chicken Dry Cat Formula
# 31                                  Dog Food Products
# 32         EASY FEED ORGANIC CHICK STARTER/GROWER ORG
# 33              Beef Cattle Feed RangeLand® 30-13 TUB
# 34  Select Small Dog Bite Size Beef & Egg Recipe D...
# 35                                        Duck treats
# 36                      Whole Capelin Fish Pet Treats
# 37                   Lactated Ringer’s Injection, USP
# 38  Lactated Ringer's Injection, USP and 0.9% Sodi...
# 39                                      Beef Cat Food
# 40                                   Dog and Cat Food
# 41                               Dog and Cat Pet Food
# 42                                           Pet Food
# 43                      Chicken and Chickpea dog food
# 44                                    Canned Dog Food
# 45                                           Pig ears
# 46                       Animal Sterile Drug Products
# 47  Alfaxan unpreserved, an intravenous injectable...
# 48              Subcutaneous injectable drug products
# 49  Liquid Probiotics for adults and toddlers; Pro...
# 50                              Complete raw pet food
# 51                              Raw pet food for cats
# 52           Raw frozen dog food turkey canine recipe
# 53  Free-Range Chicken and Turkey Recipes (Raw Die...
# 54              Omega-3 Supplements for cats and dogs
# 55  Numerous human food, animal (pet) food, medica...
# 56                    18% Goat Starter Medicated Feed
# 57                               Banamine; Banamine-S
# 58                                   Premium Dog Food
#
#                             Recall-Reason-Description  \
# 0                        Elevated Levels of Aflatoxin
# 1                 Due to elevated levels of Vitamin D
# 2   Potential Salmonella & Listeria monocytogenes ...
# 3                        Elevated levels of Vitamin D
# 4                        Elevated Levels of Vitamin D
# 5                                Potential Salmonella
# 6                            Potential choking hazard
# 7                              Pseudomonas aeruginosa
# 8                   potential of elevated urea levels
# 9                  Potential Salmonella contamination
# 10  Potential to be contaminated with Clostridium ...
# 11                 Potential Salmonella contamination
# 12                   Potential Listeria monocytogenes
# 13                                         Salmonella
# 14                                        Mislabeling
# 15                     Potentially elevated Vitamin D
# 16                                Adulterated by lead
# 17                Potential Elevated Ingredient Level
# 18             Potential Elevated Levels of Aflatoxin
# 19  As a result of a bankruptcy, the firm is remov...
# 20  Potential Salmonella contamination and presenc...
# 21                          Elevated Aflatoxin Levels
# 22                Product sterility cannot be assured
# 23                Lack of Sterility Process Assurance
# 24       Potential to be contaminated with Salmonella
# 25  Potential for Salmonella and Listeria monocyto...
# 26                          Elevated levels of copper
# 27  Due to Potential Salmonella and Listeria monoc...
# 28                 Potential Salmonella Contamination
# 29                 Potential Salmonella Contamination
# 30                 Potential Salmonella Contamination
# 31                           Salmonella contamination
# 32                  Contains deficient levels of salt
# 33  Tubs that are too soft, allowing over-consumpt...
# 34                           Potential for Salmonella
# 35       Potential to be contaminated with Salmonella
# 36                Potential for Clostridium botulinum
# 37              Presence of particulates (iron oxide)
# 38          Due to the presence of particulate matter
# 39                May be contaminated with Salmonella
# 40                       Elevated levels of aflatoxin
# 41          Aflatoxin Levels Exceed Acceptable Levels
# 42                              May Contain Aflatoxin
# 43           Potentially Elevated Levels of Vitamin D
# 44           Potentially Elevated Levels of Vitamin D
# 45                 Potential Salmonella contamination
# 46                        Lack of sterility assurance
# 47     Presence of the aluminum phosphate precipitate
# 48                                  Lack of Sterility
# 49                        Potential Foodborne Illness
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54             Potential elevated levels of Vitamin A
# 55  Potential Salmonella contamination and presenc...
# 56  Elevated level of Monovet 90 (monensin) in med...
# 57           Potential presence of particulate matter
# 58                           Salmonella contamination
#
#                            Company-Name Terminated-Recall
# 0                  Sunshine Mills, Inc.        Terminated
# 1   Wet Noses Natural Dog Treat Company        Terminated
# 2                  Top Quality Dog Food               NaN
# 3                    Fromm Family Foods        Terminated
# 4               Tuffy’s Pet Foods, Inc.        Terminated
# 5                 Woody’s Pet Food Deli               NaN
# 6                                  ALDI        Terminated
# 7                     Liva Global, Inc.        Terminated
# 8               Purina Animal Nutrition               NaN
# 9                         TFP Nutrition        Terminated
# 10                      Manzanola Feeds               NaN
# 11                        Freshpet Inc.        Terminated
# 12                Primal Pet Foods Inc.        Terminated
# 13                      Stormberg Foods               NaN
# 14        Nestle Purina PetCare Company               NaN
# 15        Nestle Purina PetCare Company        Terminated
# 16                    Bindle Bottle LLC               NaN
# 17        Nestle Purina PetCare Company               NaN
# 18                 Kaytee Products Inc.               NaN
# 19          Akorn Operating Company LLC               NaN
# 20                  Family Dollar, Inc.               NaN
# 21                        Cargill, Inc.        Terminated
# 22        Norbrook Laboratories Limited        Terminated
# 23                  RXQ Compounding LLC        Terminated
# 24              Vitakraft Sun Seed Inc.        Terminated
# 25                  Bravo Packing, Inc.        Terminated
# 26              Ridley Block Operations               NaN
# 27                  Bravo Packing, Inc.        Terminated
# 28                 Midwestern Pet Foods        Terminated
# 29                    J. M. Smucker Co.               NaN
# 30      Natural Balance Pet Foods, Inc.               NaN
# 31                 Sunshine Mills, Inc.               NaN
# 32                        Hubbard Feeds        Terminated
# 33              Purina Animal Nutrition        Terminated
# 34                        Freshpet Inc.        Terminated
# 35              Manna Pro Products, LLC        Terminated
# 36                    IcelandicPlus LLC        Terminated
# 37                     ICU Medical Inc.        Terminated
# 38                    ICU Medical, Inc.        Terminated
# 39                          Go Raw, LLC        Terminated
# 40                             Sportmix        Terminated
# 41            Midwestern Pet Foods Inc.        Terminated
# 42                 Sunshine Mills, Inc.        Terminated
# 43                              Lidl US        Terminated
# 44                 Hill's Pet Nutrition        Terminated
# 45                          Lennox Intl        Terminated
# 46             KRS Global Biotechnology        Terminated
# 47                   Jurox Incorporated        Terminated
# 48        Norbrook Laboratories Limited        Terminated
# 49                  Ozona Organics, LLC               NaN
# 50                      Blue Ridge Beef        Terminated
# 51                 Name Blue Ridge Beef               NaN
# 52                   Steve’s Real Foods        Terminated
# 53              Radagast Pet Food, Inc.        Terminated
# 54              Stratford Care USA, Inc        Terminated
# 55         Inmar Supply Chain Solutions               NaN
# 56                 Furst-McNess Company               NaN
# 57                  Merck Animal Health               NaN
# 58                 Mid America Pet Food               NaN

# %%
#### columns of this dataset
pet_food_recalls_df.columns
# Out:
# Index(['Date', 'Brand-Names', 'Product-Description',
#        'Recall-Reason-Description', 'Company-Name', 'Terminated-Recall'],
#       dtype='object')

# %% [markdown]
# ## XLSX dataset 3
