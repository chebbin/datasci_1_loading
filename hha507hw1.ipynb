# %% [markdown]
# <a href="https://colab.research.google.com/github/chebbin/datasci_1_loading/blob/main/hha507hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # CSV datasets

# %% [markdown]
# ## CSV dataset 1
#
# ### The Comprehensive Care for Joint Replacement Model: Metropolitan Statistical Areas (MSAs) dataset presents MSAs that are participating in the CMS Innovation Center Comprehensive Care for Joint Replacement Model, a model to support better and more efficient care for beneficiaries undergoing the most common inpatient surgery for Medicare beneficiaries: hip and knee replacements. Participation in this model is designated by geographic area, specifically MSAs. The information contained in the dataset can include MSA identification number, MSA geographic name and associated county or counties.

# %%
#### CSV dataset 1
joint_replacement_df = pd.read_csv('/content/joint_replacement.csv')
joint_replacement_df
# Out:
#       MSA                                       MSA Title  \
# 0   14500                                     Boulder, CO
# 1   16180                                 Carson City, NV
# 2   17860                                    Columbia, MO
# 3   19500                                     Decatur, IL
# 4   22420                                       Flint, MI
# ..    ...                                             ...
# 62  34980  Nashville-Davidson--Murfreesboro--Franklin, TN
# 63  41180                                St. Louis, MO-IL
# 64  48620                                     Wichita, KS
# 65  42660                     Seattle-Tacoma-Bellevue, WA
# 66  22500                                    Florence, SC
#
#                                              Counties
# 0                                      Boulder County
# 1                                         Carson City
# 2                                        Boone County
# 3                                        Macon County
# 4                                      Genesee County
# ..                                                ...
# 62  Cannon County, Cheatham County, Davidson Count...
# 63  Bond County, Calhoun County, Clinton County, J...
# 64  Butler County, Harvey County, Kingman County, ...
# 65       King County, Snohomish County, Pierce County
# 66                 Darlington County, Florence County
#
# [67 rows x 3 columns]

# %%
#### Columns of this data
joint_replacement_df.columns
# Out:
# Index(['MSA', 'MSA Title', 'Counties'], dtype='object')

# %%
joint_replacement_df['MSA Title']
# Out:
# 0                                        Boulder, CO
# 1                                    Carson City, NV
# 2                                       Columbia, MO
# 3                                        Decatur, IL
# 4                                          Flint, MI
#                            ...
# 62    Nashville-Davidson--Murfreesboro--Franklin, TN
# 63                                  St. Louis, MO-IL
# 64                                       Wichita, KS
# 65                       Seattle-Tacoma-Bellevue, WA
# 66                                      Florence, SC
# Name: MSA Title, Length: 67, dtype: object

# %%
joint_replacement_df['Counties']
# Out:
# 0                                        Boulder County
# 1                                           Carson City
# 2                                          Boone County
# 3                                          Macon County
# 4                                        Genesee County
#                             ...
# 62    Cannon County, Cheatham County, Davidson Count...
# 63    Bond County, Calhoun County, Clinton County, J...
# 64    Butler County, Harvey County, Kingman County, ...
# 65         King County, Snohomish County, Pierce County
# 66                   Darlington County, Florence County
# Name: Counties, Length: 67, dtype: object

# %% [markdown]
# ## CSV dataset 2
#
# ### Access-related bloodstream infections at dialysis centers

# %%
#### CSV dataset 2
access_infections_dialysis_df = pd.read_csv('/content/2015_Dialysis_AR_BSI_TABLE.csv')
access_infections_dialysis_df
# Out:
#                        Facility Name               Access Type  AR-BSI Count  \
# 0        NOBLE WOODS DIALYSIS CLINIC              Other Access             0
# 1                        FMC REDMOND              Other Access             0
# 2    PNRS EMANUEL PEDIATRIC DIALYSIS                     Graft             0
# 3    NORTHEAST PORTLAND RENAL CENTER                     Graft             0
# 4    PNRS/THC RAINES DIALYSIS CENTER                   Fistula             0
# ..                               ...                       ...           ...
# 415    USRC PORTLAND DIALYSIS CENTER                       All             7
# 416   PNRS MCMINNVILLE KIDNEY CENTER              Other Access             0
# 417                     FMC COOS BAY     Tunneled Central Line             3
# 418    MERIDIAN PARK DIALYSIS CENTER                   Fistula             0
# 419             OREGON KIDNEY CENTER  Nontunneled Central Line             0
#
#      Patient Months  AR-BSI/100 Pt. Months  National AR-BSI Mean  \
# 0                 6                   0.00                   NaN
# 1                 0                    NaN                   NaN
# 2                 0                    NaN                  0.51
# 3               265                   0.00                  0.51
# 4               370                   0.00                  0.23
# ..              ...                    ...                   ...
# 415             772                   0.91                  0.88
# 416               0                    NaN                   NaN
# 417             291                   1.03                  2.55
# 418             365                   0.00                  0.23
# 419               3                   0.00                  2.18
#
#     Comparison Interpretation  Percentile on National Distribution  \
# 0                         NaN                                  NaN
# 1                         NaN                                  NaN
# 2                         NaN                                  NaN
# 3    Better: fewer infections                                 50.0
# 4    Better: fewer infections                                 50.0
# ..                        ...                                  ...
# 415    Worse: more infections                                  NaN
# 416                       NaN                                  NaN
# 417  Better: fewer infections                                 38.0
# 418  Better: fewer infections                                 50.0
# 419  Better: fewer infections                                  NaN
#
#          County HPPRegion                                         Location 1  \
# 0    WASHINGTON   Region1                   5333 W BASELINE\nHILLSBORO 97123
# 1     DESCHUTES   Region7  916 SW 17TH STREET, SUITE 100\nREDMOND 97756\n...
# 2         UNION   Region9  10601 WALTON RD\nLA GRANDE 97850\n(45.337025, ...
# 3     MULTNOMAH   Region1  703 NE HANCOCK STREET\nPORTLAND 97212\n(45.536...
# 4    WASHINGTON   Region1  1809 MAPLE STREET\nFOREST GROVE 97116\n(45.517...
# ..          ...       ...                                                ...
# 415   MULTNOMAH   Region1  10595 SE STARK STREET\nPORTLAND 97216\n(45.519...
# 416   MULTNOMAH   Region1  2824 NE WASCO STREET, SUITE 100\nPORTLAND 9723...
# 417        COOS   Region3  1971 THOMPSON ROAD\nCOOS 97420\n(43.386065, -1...
# 418  WASHINGTON   Region1  19255 SW 65TH AVENUE, SUITE 100\nTUALATIN 9706...
# 419   MULTNOMAH   Region1  5318 NE IRVING STREET\nPORTLAND 97213\n(45.528...
#
#                                               SIR Icon
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    https://data.oregon.gov/views/4wzc-acdn/files/...
# 4    https://data.oregon.gov/views/4wzc-acdn/files/...
# ..                                                 ...
# 415  https://data.oregon.gov/views/4wzc-acdn/files/...
# 416                                                NaN
# 417  https://data.oregon.gov/views/4wzc-acdn/files/...
# 418  https://data.oregon.gov/views/4wzc-acdn/files/...
# 419  https://data.oregon.gov/views/4wzc-acdn/files/...
#
# [420 rows x 12 columns]

# %%
#### columns of this data
access_infections_dialysis_df.columns
# Out:
# Index(['Facility Name', 'Access Type', 'AR-BSI Count', 'Patient Months',
#        'AR-BSI/100 Pt. Months', 'National AR-BSI Mean',
#        'Comparison Interpretation', 'Percentile on National Distribution',
#        'County', 'HPPRegion', 'Location 1', 'SIR Icon'],
#       dtype='object')

# %% [markdown]
# :

# %%
access_infections_dialysis_df['Facility Name']
# Out:
# 0          NOBLE WOODS DIALYSIS CLINIC
# 1                          FMC REDMOND
# 2      PNRS EMANUEL PEDIATRIC DIALYSIS
# 3      NORTHEAST PORTLAND RENAL CENTER
# 4      PNRS/THC RAINES DIALYSIS CENTER
#                     ...
# 415      USRC PORTLAND DIALYSIS CENTER
# 416     PNRS MCMINNVILLE KIDNEY CENTER
# 417                       FMC COOS BAY
# 418      MERIDIAN PARK DIALYSIS CENTER
# 419               OREGON KIDNEY CENTER
# Name: Facility Name, Length: 420, dtype: object

# %%
access_infections_dialysis_df['Percentile on National Distribution']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3      50.0
# 4      50.0
#        ...
# 415     NaN
# 416     NaN
# 417    38.0
# 418    50.0
# 419     NaN
# Name: Percentile on National Distribution, Length: 420, dtype: float64

# %% [markdown]
# # JSON datasets

# %% [markdown]
# ## JSON dataset 1
#
# ### This dataset represents hospital-reported data for all pediatric patients with a diagnosis of severe sepsis or septic shock seen at New York State Article 28 (acute care) facilities and reported to the New York State Department of Health. Quality measures are calculated using this data for reporting hospital- specific rates and trends. These measures, reported as statewide and hospital-specific rates, reflect several key processes of care that can increase the probability of surviving an episode of sepsis.

# %%
data_url = ('https://health.data.ny.gov/api/views/4t82-a928/columns.json')
pediatric_sepsis_df = pd.read_json(data_url)
pediatric_sepsis_df
# Out:
#           id                                        name dataTypeName  \
# 0  414009086                              Discharge Year         text
# 1  414009085                                         PFI         text
# 2  414009092                               Facility Name         text
# 3  414009091                     Data Dictionary Version         text
# 4  414009090               Timely Antibiotic Denominator       number
# 5  414009093                      Timely Antibiotics (%)       number
# 6  414009089  Timely Antibiotics Quintile of Performance         text
# 7  414009088                   1-Hour Bundle Denominator       number
# 8  414009084                       Met 1-Hour Bundle (%)       number
# 9  414009087       1-Hour Bundle Quintile of Performance         text
#
#                                          description  \
# 0  The year of the severe sepsis or septic shock ...
# 1  The facility’s Permanent Facility Identifier (...
# 2  The name of the hospital in which the discharg...
# 3  Version of the data dictionary that was used f...
# 4  The total number of sepsis cases eligible for ...
# 5  The percentage of eligible sepsis cases for wh...
# 6  The quintile of hospital performance relative ...
# 7  The total number of sepsis cases eligible for ...
# 8  The percentage of eligible cases for whom the ...
# 9  The quintile of hospital performance relative ...
#
#                        fieldName  position renderTypeName  tableColumnId  \
# 0                 discharge_year         1           text       82858133
# 1                            pfi         2           text       82858132
# 2                  facility_name         3           text       82858139
# 3        data_dictionary_version         4           text       82858138
# 4  timely_antibiotic_denominator         5         number       82858137
# 5             timely_antibiotics         6         number       82858140
# 6    timely_antibiotics_quintile         7           text       82858136
# 7     _1_hour_bundle_denominator         8         number       82858135
# 8              met_1_hour_bundle         9         number       82858131
# 9     _1_hour_bundle_quintile_of        10           text       82858134
#
#                                       cachedContents              format
# 0  {'largest': '2017', 'non_null': '13', 'null': ...                  {}
# 1  {'largest': '003376', 'non_null': '13', 'null'...                  {}
# 2  {'largest': 'Women And Childrens Hospital Of B...                  {}
# 3  {'largest': 'v4.1', 'non_null': '13', 'null': ...                  {}
# 4  {'largest': '71', 'non_null': '13', 'null': '0...                  {}
# 5  {'largest': '100.00', 'non_null': '13', 'null'...  {'precision': '2'}
# 6  {'largest': '5-Highest', 'non_null': '13', 'nu...                  {}
# 7  {'largest': '71', 'non_null': '13', 'null': '0...                  {}
# 8  {'largest': '64.30', 'non_null': '13', 'null':...  {'precision': '2'}
# 9  {'largest': '5-Highest', 'non_null': '13', 'nu...                  {}

# %%
#### columns of this data
pediatric_sepsis_df.columns
# Out:
# Index(['id', 'name', 'dataTypeName', 'description', 'fieldName', 'position',
#        'renderTypeName', 'tableColumnId', 'cachedContents', 'format'],
#       dtype='object')

# %%
pediatric_sepsis_df['description']
# Out:
# 0    The year of the severe sepsis or septic shock ...
# 1    The facility’s Permanent Facility Identifier (...
# 2    The name of the hospital in which the discharg...
# 3    Version of the data dictionary that was used f...
# 4    The total number of sepsis cases eligible for ...
# 5    The percentage of eligible sepsis cases for wh...
# 6    The quintile of hospital performance relative ...
# 7    The total number of sepsis cases eligible for ...
# 8    The percentage of eligible cases for whom the ...
# 9    The quintile of hospital performance relative ...
# Name: description, dtype: object

# %%
pediatric_sepsis_df['name']
# Out:
# 0                                Discharge Year
# 1                                           PFI
# 2                                 Facility Name
# 3                       Data Dictionary Version
# 4                 Timely Antibiotic Denominator
# 5                        Timely Antibiotics (%)
# 6    Timely Antibiotics Quintile of Performance
# 7                     1-Hour Bundle Denominator
# 8                         Met 1-Hour Bundle (%)
# 9         1-Hour Bundle Quintile of Performance
# Name: name, dtype: object

# %% [markdown]
# ## JSON dataset 2
#
# This dataset contains the number of cases, number of in hospital/30 day deaths, observed, expected and risk- adjusted mortality rates for Percutaneous Coronary Interventions (PCI) by cardiologist. Physician information is presented for each physician who a) performed 200 or more procedures during the three year analysis and/or b) performed at least one PCI in each of the three years. The results for physicians not meeting the above criteria are grouped together and reported as “All others” in the hospital in which the procedures are performed. Regions represent where the hospitals are located. The initial Health Data NY dataset includes patients discharged between January 1, 2008, and December 31, 2010. Analyses of risk-adjusted mortality rates and associated risk factors are provided for the three-year period from 2008 through 2010. Analyses of all cases and non-emergency cases (which represent the majority of procedures) are included.

# %%
data_url = ('https://health.data.ny.gov/api/views/ekig-i57g/columns.json')
mortality_percutaneous_coronary_interventions_df = pd.read_json(data_url)
mortality_percutaneous_coronary_interventions_df
# Out:
#            id                                name dataTypeName  \
# 0   576748303                      Physician Name         text
# 1   576748304        NYS Physician License Number         text
# 2   576748319                National Provider ID         text
# 3   576748305                         Facility ID         text
# 4   576748306                       Hospital Name         text
# 5   576748307                     Detailed Region         text
# 6   576748308                              Region         text
# 7   576748309                           Procedure         text
# 8   576748310          Year of Hospital Discharge         text
# 9   576748311                     Number of Cases       number
# 10  576748312                    Number of Deaths       number
# 11  576748313             Observed Mortality Rate       number
# 12  576748314             Expected Mortality Rate       number
# 13  576748315        Risk-Adjusted Mortality Rate       number
# 14  576748316  Lower Limit of Confidence Interval       number
# 15  576748317  Upper Limit of Confidence Interval       number
# 16  576748318                  Comparison Results         text
#
#                                           description  \
# 0   Name of the physician that performed the proce...
# 1   New York State (NYS) License Number of the phy...
# 2   National Provider Identifier of the physician ...
# 3   New York State (NYS) Facility Identification N...
# 4                                       Hospital Name
# 5   New York State (NYS) License Number of the phy...
# 6         Region of hospital performing the procedure
# 7   Type of procedure performed:  All PCI, Non-Eme...
# 8         Year or range of years included in analysis
# 9                      Number of procedures performed
# 10  Number of cases resulting in death during the ...
# 11  The observed number of deaths divided by the t...
# 12  The sum of the predicted probabilities of deat...
# 13  The best estimate, based on the statistical mo...
# 14  Lower 95% confidence limit for risk adjusted m...
# 15  Upper 95% confidence limit for risk adjusted m...
# 16  A statistical test was performed to determine ...
#
#                              fieldName  position renderTypeName  \
# 0                       physician_name         1           text
# 1         nys_physician_license_number         2           text
# 2                 national_provider_id         3           text
# 3                          facility_id         4           text
# 4                        hospital_name         5           text
# 5                      detailed_region         6           text
# 6                               region         7           text
# 7                            procedure         8           text
# 8           year_of_hospital_discharge         9           text
# 9                      number_of_cases        10         number
# 10                    number_of_deaths        11         number
# 11             observed_mortality_rate        12         number
# 12             expected_mortality_rate        13         number
# 13        risk_adjusted_mortality_rate        14         number
# 14  lower_limit_of_confidence_interval        15         number
# 15  upper_limit_of_confidence_interval        16         number
# 16                  comparison_results        17           text
#
#     tableColumnId  width                                     cachedContents  \
# 0        10591450    116  {'non_null': '20531', 'largest': 'Zlotnick D',...
# 1        10591451    203  {'non_null': '20525', 'largest': '290772', 'nu...
# 2       147152356    158  {'non_null': '4491', 'largest': '1992961460', ...
# 3        10591448     77  {'non_null': '20547', 'largest': '3058', 'null...
# 4        10591449    197  {'non_null': '20529', 'largest': 'Winthrop-Uni...
# 5        10591452    177  {'non_null': '20547', 'largest': 'Western NY -...
# 6        10591453    172  {'non_null': '20547', 'largest': 'Western NY -...
# 7        10591454    121  {'non_null': '20535', 'largest': 'Non-Emergenc...
# 8        10591455    172  {'non_null': '20547', 'largest': '2017-2019', ...
# 9        10591456    119  {'non_null': '20547', 'largest': '162918', 'nu...
# 10       10591457    128  {'non_null': '20541', 'largest': '1916', 'null...
# 11       10591458    156  {'non_null': '20541', 'largest': '100', 'null'...
# 12       10591459    160  {'non_null': '20541', 'largest': '25.85', 'nul...
# 13       10591460    184  {'non_null': '20541', 'largest': '100.00', 'nu...
# 14       10591461    209  {'non_null': '20521', 'largest': '2.15', 'null...
# 15       10591462    224  {'non_null': '20521', 'largest': '100', 'null'...
# 16       10591463    274  {'non_null': '20547', 'largest': 'Statewide Ra...
#
#                                                format
# 0                                   {'align': 'left'}
# 1                                   {'align': 'left'}
# 2                                                  {}
# 3                                   {'align': 'left'}
# 4                                   {'align': 'left'}
# 5                                   {'align': 'left'}
# 6                                   {'align': 'left'}
# 7                                   {'align': 'left'}
# 8                                   {'align': 'left'}
# 9   {'precisionStyle': 'standard', 'noCommas': 'fa...
# 10  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 11  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 12  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 13  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 14  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 15  {'precisionStyle': 'standard', 'noCommas': 'fa...
# 16                                  {'align': 'left'}

# %%
#### columns of this data
mortality_percutaneous_coronary_interventions_df.columns
# Out:
# Index(['id', 'name', 'dataTypeName', 'description', 'fieldName', 'position',
#        'renderTypeName', 'tableColumnId', 'width', 'cachedContents', 'format'],
#       dtype='object')

# %%
mortality_percutaneous_coronary_interventions_df['id']
# Out:
# 0     576748303
# 1     576748304
# 2     576748319
# 3     576748305
# 4     576748306
# 5     576748307
# 6     576748308
# 7     576748309
# 8     576748310
# 9     576748311
# 10    576748312
# 11    576748313
# 12    576748314
# 13    576748315
# 14    576748316
# 15    576748317
# 16    576748318
# Name: id, dtype: int64

# %%
mortality_percutaneous_coronary_interventions_df['name']
# Out:
# 0                         Physician Name
# 1           NYS Physician License Number
# 2                   National Provider ID
# 3                            Facility ID
# 4                          Hospital Name
# 5                        Detailed Region
# 6                                 Region
# 7                              Procedure
# 8             Year of Hospital Discharge
# 9                        Number of Cases
# 10                      Number of Deaths
# 11               Observed Mortality Rate
# 12               Expected Mortality Rate
# 13          Risk-Adjusted Mortality Rate
# 14    Lower Limit of Confidence Interval
# 15    Upper Limit of Confidence Interval
# 16                    Comparison Results
# Name: name, dtype: object

# %% [markdown]
# ## JSON dataset 3
#
# ### This dataset contains the weekly estimated influenza risk level for each ZIP Code in Chicago. Estimates are made during flu season, which goes from MMWR week 40 to week 20 of the following year.

# %%
data_url = ('https://data.cityofchicago.org/api/views/8vvr-jv2g/columns.json')
flu_risk_zip_df = pd.read_json(data_url)
flu_risk_zip_df
# Out:
#            id                    name   dataTypeName  \
# 0   500557647               MMWR_Week         number
# 1   500557648              Week_Start  calendar_date
# 2   500557649                Week_End  calendar_date
# 3   500557650                ZIP_Code           text
# 4   500557651      ILI_Activity_Level         number
# 5   500557652               RECORD_ID           text
# 6   500557653       ZIP_Code_Location          point
# 7   500557654  Boundaries - ZIP Codes         number
# 8   500557655         Community Areas         number
# 9   500557656               Zip Codes         number
# 10  500557657           Census Tracts         number
# 11  500557658                   Wards         number
#
#                                           description  \
# 0   A weekly counting system within a calendar yea...
# 1                 Beginning date of the the MMWR week
# 2                        Ending date of the MMWR week
# 3                                            ZIP Code
# 4   The amount of influenza-like illness activity ...
# 5               A unique identifier for the record.\n
# 6   A point within the ZIP Code to allow for geogr...
# 7   This column was automatically created in order...
# 8   This column was automatically created in order...
# 9   This column was automatically created in order...
# 10  This column was automatically created in order...
# 11  This column was automatically created in order...
#
#                       fieldName  position renderTypeName  tableColumnId  \
# 0                     mmwr_week         1         number      118230559
# 1                    week_start         2  calendar_date      118230556
# 2                      week_end         3  calendar_date      118230555
# 3                      zip_code         4           text      118230554
# 4            ili_activity_level         5         number      118230558
# 5                     record_id         6           text      118230560
# 6             zip_code_location         7          point      118230557
# 7   :@computed_region_rpca_8um6         8         number      118230561
# 8   :@computed_region_vrxf_vc4k         9         number      118230562
# 9   :@computed_region_6mkv_f3dw        10         number      118230563
# 10  :@computed_region_bdys_3d7i        11         number      118230564
# 11  :@computed_region_43wa_7qmu        12         number      118230565
#
#                                        cachedContents            format  \
# 0   {'non_null': '10881', 'largest': '53', 'null':...                {}
# 1   {'non_null': '10881', 'largest': '2023-08-20T0...  {'view': 'date'}
# 2   {'non_null': '10881', 'largest': '2023-08-26T0...  {'view': 'date'}
# 3   {'non_null': '10881', 'largest': '60827', 'nul...                {}
# 4   {'non_null': '10881', 'largest': '10', 'null':...                {}
# 5   {'non_null': '10881', 'largest': '2023-34-6082...                {}
# 6   {'non_null': '10881', 'null': '0', 'top': [{'i...                {}
# 7                                                 NaN                {}
# 8                                                 NaN                {}
# 9                                                 NaN                {}
# 10                                                NaN                {}
# 11                                                NaN                {}
#
#                                   computationStrategy
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'source_columns': ['zip_code_location'], 'typ...
# 8   {'source_columns': ['zip_code_location'], 'typ...
# 9   {'source_columns': ['zip_code_location'], 'typ...
# 10  {'source_columns': ['zip_code_location'], 'typ...
# 11  {'source_columns': ['zip_code_location'], 'typ...

# %%
#### columns of this data

flu_risk_zip_df.columns
# Out:
# Index(['id', 'name', 'dataTypeName', 'description', 'fieldName', 'position',
#        'renderTypeName', 'tableColumnId', 'cachedContents', 'format',
#        'computationStrategy'],
#       dtype='object')

# %%
flu_risk_zip_df['description']
# Out:
# 0     A weekly counting system within a calendar yea...
# 1                   Beginning date of the the MMWR week
# 2                          Ending date of the MMWR week
# 3                                              ZIP Code
# 4     The amount of influenza-like illness activity ...
# 5                 A unique identifier for the record.\n
# 6     A point within the ZIP Code to allow for geogr...
# 7     This column was automatically created in order...
# 8     This column was automatically created in order...
# 9     This column was automatically created in order...
# 10    This column was automatically created in order...
# 11    This column was automatically created in order...
# Name: description, dtype: object

# %%
flu_risk_zip_df['fieldName']
# Out:
# 0                       mmwr_week
# 1                      week_start
# 2                        week_end
# 3                        zip_code
# 4              ili_activity_level
# 5                       record_id
# 6               zip_code_location
# 7     :@computed_region_rpca_8um6
# 8     :@computed_region_vrxf_vc4k
# 9     :@computed_region_6mkv_f3dw
# 10    :@computed_region_bdys_3d7i
# 11    :@computed_region_43wa_7qmu
# Name: fieldName, dtype: object

# %% [markdown]
# # XLSX datasets

# %% [markdown]
# ## XLSX dataset 1
#
# ### This dataset provides data for new prescription drugs introduced to market in California with a Wholesale Acquisition Cost (WAC) that exceeds the Medicare Part D specialty drug cost threshold. Prescription drug manufacturers submit information to HCAI within a specified time period after a drug is introduced to market. Key data elements include the National Drug Code (NDC) administered by the FDA, a narrative description of marketing and pricing plans, and WAC, among other information.

# %%
#### XLSX dataset 1

new_drugs_df = pd.read_excel('/content/new-drug-report-q1-q4-2022.xlsx')
new_drugs_df
# Out:
#                     Manufacturer Name   NDC Number  \
# 0               Aadi Bioscience, Inc.  80803015350
# 1                              AbbVie     74231030
# 2                              AbbVie     74104328
# 3                              AbbVie     74501501
# 4                              AbbVie     74107001
# ..                                ...          ...
# 342  Zydus Pharmaceuticals (USA) Inc.  70710103207
# 343  Zydus Pharmaceuticals (USA) Inc.  70710103308
# 344  Zydus Pharmaceuticals (USA) Inc.  70710103508
# 345  Zydus Pharmaceuticals (USA) Inc.  70710103107
# 346  Zydus Pharmaceuticals (USA) Inc.  68382091206
#
#                               Drug Product Description  \
# 0    FYARRO™ (sirolimus protein-bound particles for...
# 1             RINVOQ (upadacitinib) 30MG 30 Day Bottle
# 2             RINVOQ (upadacitinib) 45MG 30 Day Bottle
# 3                               RISA 600mg / 10mL VIAL
# 4                          SKYRIZI (risankizumab-rzaa)
# ..                                                 ...
# 342                Lenalidomide 10mg Capsule (28 CAPS)
# 343                Lenalidomide 15mg Capsule (21 CAPS)
# 344                Lenalidomide 25mg Capsule (21 CAPS)
# 345                 Lenalidomide 5mg Capsule (28 CAPS)
# 346                 Fingolimod 0.5mg Capsule (30 Caps)
#
#     Date Introduced to Market  WAC at Introduction  \
# 0                  2022-02-22              6785.00
# 1                  2022-01-24              5671.26
# 2                  2022-03-23             10586.24
# 3                  2022-06-28              9136.40
# 4                  2022-08-23             18272.79
# ..                        ...                  ...
# 342                2022-09-14             20157.36
# 343                2022-09-14             15118.04
# 344                2022-09-14             15118.04
# 345                2022-09-14             20157.36
# 346                2022-10-20              2220.97
#
#                     Marketing/Pricing Plan Description  \
# 0                                                  NaN
# 1    RINVOQ is marketed for the treatment of refrac...
# 2    RINVOQ is marketed to treat adults with modera...
# 3    SKYRIZI is marketed for the treatment of moder...
# 4    SKYRIZI is marketed for the treatment of moder...
# ..                                                 ...
# 342                                                NaN
# 343                                                NaN
# 344                                                NaN
# 345                                                NaN
# 346                                                NaN
#
#      Marketing/Pricing Plan Non-Public Indicator  \
# 0                                            1.0
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 342                                          1.0
# 343                                          1.0
# 344                                          1.0
# 345                                          1.0
# 346                                          1.0
#
#      Estimated Number of Patients  Breakthrough Therapy Indicator  \
# 0                           300.0                             1.0
# 1                         12000.0                             1.0
# 2                          7200.0                             NaN
# 3                          1000.0                             NaN
# 4                          1000.0                             NaN
# ..                            ...                             ...
# 342                       60000.0                             NaN
# 343                       60000.0                             NaN
# 344                       60000.0                             NaN
# 345                       60000.0                             NaN
# 346                      913925.0                             NaN
#
#      Priority Review Indicator Acquisition Date  Acquisition Price  \
# 0                          1.0              NaN                NaN
# 1                          1.0              NaN                NaN
# 2                          1.0              NaN                NaN
# 3                          1.0              NaN                NaN
# 4                          1.0              NaN                NaN
# ..                         ...              ...                ...
# 342                        NaN              NaN                NaN
# 343                        NaN              NaN                NaN
# 344                        NaN              NaN                NaN
# 345                        NaN              NaN                NaN
# 346                        NaN              NaN                NaN
#
#      Acquisition Price Non-Public Indicator Acquisition Price Comment  \
# 0                                       NaN                       NaN
# 1                                       NaN                       NaN
# 2                                       NaN                       NaN
# 3                                       NaN                       NaN
# 4                                       NaN                       NaN
# ..                                      ...                       ...
# 342                                     NaN                       NaN
# 343                                     NaN                       NaN
# 344                                     NaN                       NaN
# 345                                     NaN                       NaN
# 346                                     NaN                       NaN
#
#                                       General Comments Supporting Documents
# 0    "Aadi has listed Fyarro with a WAC price effec...                  NaN
# 1    Response on estimated volume of patients: RINV...                  NaN
# 2                                                  NaN                  NaN
# 3    Response on estimated volume of patients (1,00...                  NaN
# 4    Response on estimated volume of patients (1,00...                  NaN
# ..                                                 ...                  ...
# 342  This is an AB rated generic product that was d...                  NaN
# 343  This is an AB rated generic product that was d...                  NaN
# 344  This is an AB rated generic product that was d...                  NaN
# 345  This is an AB rated generic product that was d...                  NaN
# 346  This is an AB rated generic product that was d...                  NaN
#
# [347 rows x 16 columns]

# %%
#### columns of this data
new_drugs_df.columns
# Out:
# Index(['Manufacturer Name', 'NDC Number', 'Drug Product Description',
#        'Date Introduced to Market', 'WAC at Introduction',
#        'Marketing/Pricing Plan Description',
#        'Marketing/Pricing Plan Non-Public Indicator',
#        'Estimated Number of Patients', 'Breakthrough Therapy Indicator',
#        'Priority Review Indicator', 'Acquisition Date', 'Acquisition Price',
#        'Acquisition Price Non-Public Indicator', 'Acquisition Price Comment',
#        'General Comments', 'Supporting Documents'],
#       dtype='object')

# %%
new_drugs_df['Manufacturer Name']
# Out:
# 0                 Aadi Bioscience, Inc.
# 1                                AbbVie
# 2                                AbbVie
# 3                                AbbVie
# 4                                AbbVie
#                      ...
# 342    Zydus Pharmaceuticals (USA) Inc.
# 343    Zydus Pharmaceuticals (USA) Inc.
# 344    Zydus Pharmaceuticals (USA) Inc.
# 345    Zydus Pharmaceuticals (USA) Inc.
# 346    Zydus Pharmaceuticals (USA) Inc.
# Name: Manufacturer Name, Length: 347, dtype: object

# %%
new_drugs_df['Drug Product Description']
# Out:
# 0      FYARRO™ (sirolimus protein-bound particles for...
# 1               RINVOQ (upadacitinib) 30MG 30 Day Bottle
# 2               RINVOQ (upadacitinib) 45MG 30 Day Bottle
# 3                                 RISA 600mg / 10mL VIAL
# 4                            SKYRIZI (risankizumab-rzaa)
#                              ...
# 342                  Lenalidomide 10mg Capsule (28 CAPS)
# 343                  Lenalidomide 15mg Capsule (21 CAPS)
# 344                  Lenalidomide 25mg Capsule (21 CAPS)
# 345                   Lenalidomide 5mg Capsule (28 CAPS)
# 346                   Fingolimod 0.5mg Capsule (30 Caps)
# Name: Drug Product Description, Length: 347, dtype: object

# %% [markdown]
# ## XLSX dataset 2
#
# ### FDA pet food recalls

# %%
#### XLSX dataset 2

pet_food_recalls_df = pd.read_excel('/content/cvm-recalls.xlsx')
pet_food_recalls_df
# Out:
#           Date                                        Brand-Names  \
# 0   07/29/2021      Triumph, Evolve, Nature Farms, Elm and others
# 1   08/13/2021                                     Simply Nourish
# 2   08/26/2021                           Top Quality Dog Food.com
# 3   10/01/2021                       Fromm Four-Star Nutritionals
# 4   10/12/2021                                       Nutri Source
# 5   12/23/2021                              Woody's Pet Food Deli
# 6   01/04/2022                                         Pure Being
# 7   12/01/2021                             LivaOne and BioLifePet
# 8   10/27/2021                                             Purina
# 9   12/16/2022                                     HEB TEXAS PETS
# 10  12/16/2022                                 Top of the Rockies
# 11  06/18/2022                                           Freshpet
# 12  07/06/2022                              Primal Pet Foods Inc.
# 13  07/12/2022  Beg & Barker, Billo’s Best Friend, and Green C...
# 14  12/02/2022                                             Purina
# 15  02/08/2023                                             Purina
# 16  02/23/2023                                  Bindle Bottle LLC
# 17  03/10/2023                                             Purina
# 18  03/20/2023                                             Kaytee
# 19  05/04/2023                                    Numerous Brands
# 20  02/18/2022                               Numerous brand names
# 21  05/06/2019                                    Southern States
# 22  05/24/2019                                           Norbrook
# 23  06/18/2019                                RXQ Compounding LLC
# 24  03/01/2021                                          Vitakraft
# 25  03/03/2021                                Bravo Packing, Inc.
# 26  03/03/2021                            Ridley Block Operations
# 27  03/16/2021                                Bravo Packing, Inc.
# 28  03/27/2021                                    Multiple brands
# 29  04/12/2021                                          Meow Mix®
# 30  05/20/2021                                    Natural Balance
# 31  06/03/2021  Sportsman’s Pride, Sprout Sporting, Intimidato...
# 32  06/08/2021                                      Hubbard Feeds
# 33  06/11/2021                                             Purina
# 34  06/13/2021                                           Freshpet
# 35  06/29/2021                                        Flock Party
# 36  03/23/2020                                         Icelandic+
# 37  05/08/2020                                   ICU Medical Inc.
# 38  10/30/2019                                  ICU Medical, Inc.
# 39  11/18/2019                                              Quest
# 40  12/30/2020                                           Sportmix
# 41  01/11/2021          Sportmix, Nunn Better, ProPac, and Others
# 42  10/08/2020           Champ, Field Trial, Good Dog, and Others
# 43  03/16/2020                                            Orlando
# 44  01/31/2019                                Hill's Science Diet
# 45  07/26/2019                                             Lennox
# 46  09/12/2019                           KRS Global Biotechnology
# 47  04/24/2019                                              Jurox
# 48  04/29/2019                      Norbrook Laboratories Limited
# 49  08/01/2023                                  Ozona, Go Healthy
# 50  03/26/2018                                    Blue Ridge Beef
# 51  03/02/2018                                    Blue Ridge Beef
# 52  03/02/2018                                 Steve’s Real Foods
# 53  03/20/2018                                            Rad Cat
# 54  03/10/2023                                    Multiple brands
# 55  08/23/2023                               Numerous brand names
# 56  08/25/2023                                             McNess
# 57  09/01/2023                                Merck Animal Health
# 58  09/04/2023                                             Victor
#
#                                   Product-Description  \
# 0                                            Dog Food
# 1                                     Frozen dog food
# 2                                            Beef HVM
# 3                     Shredded Entrée canned dog food
# 4                    Pure Vita Salmon Entrée Dog Food
# 5         Raw Cornish Hen pet food “With Supplements”
# 6                  Advent Calendars for Cats and Dogs
# 7                                          Probiotics
# 8   Supplement feed for cattle livestock and for w...
# 9         HEB TEXAS PETS Indoor Complete Dry Cat Food
# 10                                      Alfalfa Cubes
# 11  Freshpet Select Fresh From the Kitchen Home Co...
# 12    Raw Frozen Primal Patties for Dogs Beef Formula
# 13                                 Chicken dog treats
# 14  Purina Pro Plan Veterinary Diets EN Gastroente...
# 15         Veterinary Diets EL Elemental Dry Dog Food
# 16                                            Bottles
# 17  Pro Plan Veterinary Diets EL Elemental (PPVD E...
# 18                      Wild Bird Food Birders’ Blend
# 19             Various human and animal drug products
# 20  Numerous human food, animal (pet) food, medica...
# 21                                Various animal feed
# 22                Veterinary injectable drug products
# 23  All sterile human and animal products within e...
# 24                           Vita Smart Hedgehog Food
# 25  Ground Beef and Performance Dog, frozen raw pe...
# 26                                CRYSTALYX Sheep-lyx
# 27  Pet food: Performance Dog, beef, green tripe, ...
# 28                                   Dog and Cat Food
# 29             Meow Mix® Original Choice Dry Cat Food
# 30         L.I.D. Green Pea & Chicken Dry Cat Formula
# 31                                  Dog Food Products
# 32         EASY FEED ORGANIC CHICK STARTER/GROWER ORG
# 33              Beef Cattle Feed RangeLand® 30-13 TUB
# 34  Select Small Dog Bite Size Beef & Egg Recipe D...
# 35                                        Duck treats
# 36                      Whole Capelin Fish Pet Treats
# 37                   Lactated Ringer’s Injection, USP
# 38  Lactated Ringer's Injection, USP and 0.9% Sodi...
# 39                                      Beef Cat Food
# 40                                   Dog and Cat Food
# 41                               Dog and Cat Pet Food
# 42                                           Pet Food
# 43                      Chicken and Chickpea dog food
# 44                                    Canned Dog Food
# 45                                           Pig ears
# 46                       Animal Sterile Drug Products
# 47  Alfaxan unpreserved, an intravenous injectable...
# 48              Subcutaneous injectable drug products
# 49  Liquid Probiotics for adults and toddlers; Pro...
# 50                              Complete raw pet food
# 51                              Raw pet food for cats
# 52           Raw frozen dog food turkey canine recipe
# 53  Free-Range Chicken and Turkey Recipes (Raw Die...
# 54              Omega-3 Supplements for cats and dogs
# 55  Numerous human food, animal (pet) food, medica...
# 56                    18% Goat Starter Medicated Feed
# 57                               Banamine; Banamine-S
# 58                                   Premium Dog Food
#
#                             Recall-Reason-Description  \
# 0                        Elevated Levels of Aflatoxin
# 1                 Due to elevated levels of Vitamin D
# 2   Potential Salmonella & Listeria monocytogenes ...
# 3                        Elevated levels of Vitamin D
# 4                        Elevated Levels of Vitamin D
# 5                                Potential Salmonella
# 6                            Potential choking hazard
# 7                              Pseudomonas aeruginosa
# 8                   potential of elevated urea levels
# 9                  Potential Salmonella contamination
# 10  Potential to be contaminated with Clostridium ...
# 11                 Potential Salmonella contamination
# 12                   Potential Listeria monocytogenes
# 13                                         Salmonella
# 14                                        Mislabeling
# 15                     Potentially elevated Vitamin D
# 16                                Adulterated by lead
# 17                Potential Elevated Ingredient Level
# 18             Potential Elevated Levels of Aflatoxin
# 19  As a result of a bankruptcy, the firm is remov...
# 20  Potential Salmonella contamination and presenc...
# 21                          Elevated Aflatoxin Levels
# 22                Product sterility cannot be assured
# 23                Lack of Sterility Process Assurance
# 24       Potential to be contaminated with Salmonella
# 25  Potential for Salmonella and Listeria monocyto...
# 26                          Elevated levels of copper
# 27  Due to Potential Salmonella and Listeria monoc...
# 28                 Potential Salmonella Contamination
# 29                 Potential Salmonella Contamination
# 30                 Potential Salmonella Contamination
# 31                           Salmonella contamination
# 32                  Contains deficient levels of salt
# 33  Tubs that are too soft, allowing over-consumpt...
# 34                           Potential for Salmonella
# 35       Potential to be contaminated with Salmonella
# 36                Potential for Clostridium botulinum
# 37              Presence of particulates (iron oxide)
# 38          Due to the presence of particulate matter
# 39                May be contaminated with Salmonella
# 40                       Elevated levels of aflatoxin
# 41          Aflatoxin Levels Exceed Acceptable Levels
# 42                              May Contain Aflatoxin
# 43           Potentially Elevated Levels of Vitamin D
# 44           Potentially Elevated Levels of Vitamin D
# 45                 Potential Salmonella contamination
# 46                        Lack of sterility assurance
# 47     Presence of the aluminum phosphate precipitate
# 48                                  Lack of Sterility
# 49                        Potential Foodborne Illness
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54             Potential elevated levels of Vitamin A
# 55  Potential Salmonella contamination and presenc...
# 56  Elevated level of Monovet 90 (monensin) in med...
# 57           Potential presence of particulate matter
# 58                           Salmonella contamination
#
#                            Company-Name Terminated-Recall
# 0                  Sunshine Mills, Inc.        Terminated
# 1   Wet Noses Natural Dog Treat Company        Terminated
# 2                  Top Quality Dog Food               NaN
# 3                    Fromm Family Foods        Terminated
# 4               Tuffy’s Pet Foods, Inc.        Terminated
# 5                 Woody’s Pet Food Deli               NaN
# 6                                  ALDI        Terminated
# 7                     Liva Global, Inc.        Terminated
# 8               Purina Animal Nutrition               NaN
# 9                         TFP Nutrition        Terminated
# 10                      Manzanola Feeds               NaN
# 11                        Freshpet Inc.        Terminated
# 12                Primal Pet Foods Inc.        Terminated
# 13                      Stormberg Foods               NaN
# 14        Nestle Purina PetCare Company               NaN
# 15        Nestle Purina PetCare Company        Terminated
# 16                    Bindle Bottle LLC               NaN
# 17        Nestle Purina PetCare Company               NaN
# 18                 Kaytee Products Inc.               NaN
# 19          Akorn Operating Company LLC               NaN
# 20                  Family Dollar, Inc.               NaN
# 21                        Cargill, Inc.        Terminated
# 22        Norbrook Laboratories Limited        Terminated
# 23                  RXQ Compounding LLC        Terminated
# 24              Vitakraft Sun Seed Inc.        Terminated
# 25                  Bravo Packing, Inc.        Terminated
# 26              Ridley Block Operations               NaN
# 27                  Bravo Packing, Inc.        Terminated
# 28                 Midwestern Pet Foods        Terminated
# 29                    J. M. Smucker Co.               NaN
# 30      Natural Balance Pet Foods, Inc.               NaN
# 31                 Sunshine Mills, Inc.               NaN
# 32                        Hubbard Feeds        Terminated
# 33              Purina Animal Nutrition        Terminated
# 34                        Freshpet Inc.        Terminated
# 35              Manna Pro Products, LLC        Terminated
# 36                    IcelandicPlus LLC        Terminated
# 37                     ICU Medical Inc.        Terminated
# 38                    ICU Medical, Inc.        Terminated
# 39                          Go Raw, LLC        Terminated
# 40                             Sportmix        Terminated
# 41            Midwestern Pet Foods Inc.        Terminated
# 42                 Sunshine Mills, Inc.        Terminated
# 43                              Lidl US        Terminated
# 44                 Hill's Pet Nutrition        Terminated
# 45                          Lennox Intl        Terminated
# 46             KRS Global Biotechnology        Terminated
# 47                   Jurox Incorporated        Terminated
# 48        Norbrook Laboratories Limited        Terminated
# 49                  Ozona Organics, LLC               NaN
# 50                      Blue Ridge Beef        Terminated
# 51                 Name Blue Ridge Beef               NaN
# 52                   Steve’s Real Foods        Terminated
# 53              Radagast Pet Food, Inc.        Terminated
# 54              Stratford Care USA, Inc        Terminated
# 55         Inmar Supply Chain Solutions               NaN
# 56                 Furst-McNess Company               NaN
# 57                  Merck Animal Health               NaN
# 58                 Mid America Pet Food               NaN

# %%
#### columns of this dataset
pet_food_recalls_df.columns
# Out:
# Index(['Date', 'Brand-Names', 'Product-Description',
#        'Recall-Reason-Description', 'Company-Name', 'Terminated-Recall'],
#       dtype='object')

# %%
pet_food_recalls_df['Brand-Names']
# Out:
# 0         Triumph, Evolve, Nature Farms, Elm and others
# 1                                        Simply Nourish
# 2                              Top Quality Dog Food.com
# 3                          Fromm Four-Star Nutritionals
# 4                                          Nutri Source
# 5                                 Woody's Pet Food Deli
# 6                                            Pure Being
# 7                                LivaOne and BioLifePet
# 8                                                Purina
# 9                                        HEB TEXAS PETS
# 10                                   Top of the Rockies
# 11                                             Freshpet
# 12                                Primal Pet Foods Inc.
# 13    Beg & Barker, Billo’s Best Friend, and Green C...
# 14                                               Purina
# 15                                               Purina
# 16                                    Bindle Bottle LLC
# 17                                               Purina
# 18                                               Kaytee
# 19                                      Numerous Brands
# 20                                 Numerous brand names
# 21                                      Southern States
# 22                                             Norbrook
# 23                                  RXQ Compounding LLC
# 24                                            Vitakraft
# 25                                  Bravo Packing, Inc.
# 26                              Ridley Block Operations
# 27                                  Bravo Packing, Inc.
# 28                                      Multiple brands
# 29                                            Meow Mix®
# 30                                      Natural Balance
# 31    Sportsman’s Pride, Sprout Sporting, Intimidato...
# 32                                        Hubbard Feeds
# 33                                               Purina
# 34                                             Freshpet
# 35                                          Flock Party
# 36                                           Icelandic+
# 37                                     ICU Medical Inc.
# 38                                    ICU Medical, Inc.
# 39                                                Quest
# 40                                             Sportmix
# 41            Sportmix, Nunn Better, ProPac, and Others
# 42             Champ, Field Trial, Good Dog, and Others
# 43                                              Orlando
# 44                                  Hill's Science Diet
# 45                                               Lennox
# 46                             KRS Global Biotechnology
# 47                                                Jurox
# 48                        Norbrook Laboratories Limited
# 49                                    Ozona, Go Healthy
# 50                                      Blue Ridge Beef
# 51                                      Blue Ridge Beef
# 52                                   Steve’s Real Foods
# 53                                              Rad Cat
# 54                                      Multiple brands
# 55                                 Numerous brand names
# 56                                               McNess
# 57                                  Merck Animal Health
# 58                                               Victor
# Name: Brand-Names, dtype: object

# %%
pet_food_recalls_df['Company-Name']
# Out:
# 0                    Sunshine Mills, Inc.
# 1     Wet Noses Natural Dog Treat Company
# 2                    Top Quality Dog Food
# 3                      Fromm Family Foods
# 4                 Tuffy’s Pet Foods, Inc.
# 5                   Woody’s Pet Food Deli
# 6                                    ALDI
# 7                       Liva Global, Inc.
# 8                 Purina Animal Nutrition
# 9                           TFP Nutrition
# 10                        Manzanola Feeds
# 11                          Freshpet Inc.
# 12                  Primal Pet Foods Inc.
# 13                        Stormberg Foods
# 14          Nestle Purina PetCare Company
# 15          Nestle Purina PetCare Company
# 16                      Bindle Bottle LLC
# 17          Nestle Purina PetCare Company
# 18                   Kaytee Products Inc.
# 19            Akorn Operating Company LLC
# 20                    Family Dollar, Inc.
# 21                          Cargill, Inc.
# 22          Norbrook Laboratories Limited
# 23                    RXQ Compounding LLC
# 24                Vitakraft Sun Seed Inc.
# 25                    Bravo Packing, Inc.
# 26                Ridley Block Operations
# 27                    Bravo Packing, Inc.
# 28                   Midwestern Pet Foods
# 29                      J. M. Smucker Co.
# 30        Natural Balance Pet Foods, Inc.
# 31                   Sunshine Mills, Inc.
# 32                          Hubbard Feeds
# 33                Purina Animal Nutrition
# 34                          Freshpet Inc.
# 35                Manna Pro Products, LLC
# 36                      IcelandicPlus LLC
# 37                       ICU Medical Inc.
# 38                      ICU Medical, Inc.
# 39                            Go Raw, LLC
# 40                               Sportmix
# 41              Midwestern Pet Foods Inc.
# 42                   Sunshine Mills, Inc.
# 43                                Lidl US
# 44                   Hill's Pet Nutrition
# 45                            Lennox Intl
# 46               KRS Global Biotechnology
# 47                     Jurox Incorporated
# 48          Norbrook Laboratories Limited
# 49                    Ozona Organics, LLC
# 50                        Blue Ridge Beef
# 51                   Name Blue Ridge Beef
# 52                     Steve’s Real Foods
# 53                Radagast Pet Food, Inc.
# 54                Stratford Care USA, Inc
# 55           Inmar Supply Chain Solutions
# 56                   Furst-McNess Company
# 57                    Merck Animal Health
# 58                   Mid America Pet Food
# Name: Company-Name, dtype: object

# %% [markdown]
# ## XLSX dataset 3
#
# ###Health and Safety Code section 1288.7(a) requires California acute care hospitals to offer influenza vaccine free of charge to all healthcare providers (HCP) or sign a declination form if a HCP chooses not to be vaccinated. Hospitals must report HCP influenza vaccination data to the California Department of Public Health (CDPH), including the percentage of HCP vaccinated. CDPH is required to make this information public on an annual basis [Health and Safety Code section 1288.8 (b)].

# %%
#### XLSX dataset 3

fluvaccine_df = pd.read_excel('/content/odp_hcp_vax_by_county_2022-23_season_051623.xlsx')
fluvaccine_df
# Out:
#    Influenza_Season       State  \
# 0           2022-23  California
# 1           2022-23  California
# 2           2022-23  California
# 3           2022-23  California
# 4           2022-23  California
# 5           2022-23  California
# 6           2022-23  California
# 7           2022-23  California
# 8           2022-23  California
# 9           2022-23  California
# 10          2022-23  California
# 11          2022-23  California
# 12          2022-23  California
# 13          2022-23  California
# 14          2022-23  California
# 15          2022-23  California
# 16          2022-23  California
# 17          2022-23  California
# 18          2022-23  California
# 19          2022-23  California
# 20          2022-23  California
# 21          2022-23  California
# 22          2022-23  California
# 23          2022-23  California
# 24          2022-23  California
# 25          2022-23  California
# 26          2022-23  California
# 27          2022-23  California
# 28          2022-23  California
# 29          2022-23  California
# 30          2022-23  California
# 31          2022-23  California
# 32          2022-23  California
# 33          2022-23  California
# 34          2022-23  California
# 35          2022-23  California
# 36          2022-23  California
# 37          2022-23  California
# 38          2022-23  California
# 39          2022-23  California
# 40          2022-23  California
# 41          2022-23  California
# 42          2022-23  California
# 43          2022-23  California
# 44          2022-23  California
# 45          2022-23  California
# 46          2022-23  California
# 47          2022-23  California
# 48          2022-23  California
# 49          2022-23  California
# 50          2022-23  California
# 51          2022-23  California
# 52          2022-23  California
# 53          2022-23  California
# 54          2022-23  California
# 55          2022-23  California
# 56          2022-23  California
#
#                          CDPH_HAI_HCP_FLU_VACCINATION               County  \
# 0   California Department of Public Health, Health...  State of California
# 1   California Department of Public Health, Health...              Alameda
# 2   California Department of Public Health, Health...               Amador
# 3   California Department of Public Health, Health...                Butte
# 4   California Department of Public Health, Health...            Calaveras
# 5   California Department of Public Health, Health...               Colusa
# 6   California Department of Public Health, Health...         Contra Costa
# 7   California Department of Public Health, Health...            Del Norte
# 8   California Department of Public Health, Health...            El Dorado
# 9   California Department of Public Health, Health...               Fresno
# 10  California Department of Public Health, Health...                Glenn
# 11  California Department of Public Health, Health...             Humboldt
# 12  California Department of Public Health, Health...             Imperial
# 13  California Department of Public Health, Health...                 Inyo
# 14  California Department of Public Health, Health...                 Kern
# 15  California Department of Public Health, Health...                Kings
# 16  California Department of Public Health, Health...                 Lake
# 17  California Department of Public Health, Health...               Lassen
# 18  California Department of Public Health, Health...          Los Angeles
# 19  California Department of Public Health, Health...               Madera
# 20  California Department of Public Health, Health...                Marin
# 21  California Department of Public Health, Health...             Mariposa
# 22  California Department of Public Health, Health...            Mendocino
# 23  California Department of Public Health, Health...               Merced
# 24  California Department of Public Health, Health...                Modoc
# 25  California Department of Public Health, Health...                 Mono
# 26  California Department of Public Health, Health...             Monterey
# 27  California Department of Public Health, Health...                 Napa
# 28  California Department of Public Health, Health...               Nevada
# 29  California Department of Public Health, Health...               Orange
# 30  California Department of Public Health, Health...               Placer
# 31  California Department of Public Health, Health...               Plumas
# 32  California Department of Public Health, Health...            Riverside
# 33  California Department of Public Health, Health...           Sacramento
# 34  California Department of Public Health, Health...           San Benito
# 35  California Department of Public Health, Health...       San Bernardino
# 36  California Department of Public Health, Health...            San Diego
# 37  California Department of Public Health, Health...        San Francisco
# 38  California Department of Public Health, Health...          San Joaquin
# 39  California Department of Public Health, Health...      San Luis Obispo
# 40  California Department of Public Health, Health...            San Mateo
# 41  California Department of Public Health, Health...        Santa Barbara
# 42  California Department of Public Health, Health...          Santa Clara
# 43  California Department of Public Health, Health...           Santa Cruz
# 44  California Department of Public Health, Health...               Shasta
# 45  California Department of Public Health, Health...             Siskiyou
# 46  California Department of Public Health, Health...               Solano
# 47  California Department of Public Health, Health...               Sonoma
# 48  California Department of Public Health, Health...           Stanislaus
# 49  California Department of Public Health, Health...               Sutter
# 50  California Department of Public Health, Health...               Tehama
# 51  California Department of Public Health, Health...              Trinity
# 52  California Department of Public Health, Health...               Tulare
# 53  California Department of Public Health, Health...             Tuolumne
# 54  California Department of Public Health, Health...              Ventura
# 55  California Department of Public Health, Health...                 Yolo
# 56  California Department of Public Health, Health...                 Yuba
#
#    order_this_season  Number_Hospitals  HCP_Total_Number_Vaccinated  \
# 0                NaN               396                       710267
# 1                Yes                14                        29830
# 2                Yes                 1                         1239
# 3                Yes                 4                         4300
# 4                Yes                 1                          326
# 5                Yes                 1                          208
# 6                Yes                 8                        15416
# 7                Yes                 1                          369
# 8                Yes                 2                         2124
# 9                Yes                10                        22276
# 10               Yes                 1                          238
# 11               Yes                 5                         2026
# 12               Yes                 2                         2032
# 13               Yes                 2                          435
# 14               Yes                12                        13560
# 15               Yes                 1                         1630
# 16               Yes                 2                         1285
# 17               Yes                 1                          307
# 18               Yes                90                       185409
# 19               Yes                 2                         4703
# 20               Yes                 4                         5070
# 21               Yes                 1                          133
# 22               Yes                 3                         2449
# 23               Yes                 2                         2134
# 24               Yes                 2                          167
# 25               Yes                 1                          293
# 26               Yes                 4                         6685
# 27               Yes                 2                         2586
# 28               Yes                 2                         1894
# 29               Yes                34                        59143
# 30               Yes                 3                         8767
# 31               Yes                 3                          468
# 32               Yes                20                        24406
# 33               Yes                10                        34111
# 34               Yes                 1                          585
# 35               Yes                25                        37173
# 36               Yes                22                        63759
# 37               Yes                13                        42414
# 38               Yes                 7                         9800
# 39               Yes                 4                         3002
# 40               Yes                 6                         9291
# 41               Yes                 5                         7170
# 42               Yes                12                        45679
# 43               Yes                 3                         3027
# 44               Yes                 4                         3001
# 45               Yes                 2                          849
# 46               Yes                 5                         6598
# 47               Yes                 7                         8302
# 48               Yes                 8                         9659
# 49               Yes                 1                          113
# 50               Yes                 1                          811
# 51               Yes                 1                          123
# 52               Yes                 4                         5574
# 53               Yes                 1                         1252
# 54               Yes                10                        11453
# 55               Yes                 2                         1763
# 56               Yes                 1                         2850
#
#     HCP_Total_Number_Working  AllHCP_FluVaccPerc_r  Emp_Number_Vaccinated  \
# 0                     962868                    74                 489511
# 1                      38265                    78                  21050
# 2                       1603                    77                    306
# 3                       8082                    53                   2935
# 4                        450                    72                    219
# 5                        424                    49                    143
# 6                      23169                    67                  11653
# 7                        537                    69                    269
# 8                       3118                    68                   1754
# 9                      25816                    86                  16181
# 10                       535                    44                    166
# 11                      3069                    66                   1487
# 12                      3008                    68                   1540
# 13                       700                    62                    305
# 14                     17884                    76                   8683
# 15                      1789                    91                   1189
# 16                      1625                    79                    871
# 17                       353                    87                    256
# 18                    249940                    74                 127723
# 19                      5487                    86                   4174
# 20                      6323                    80                   4015
# 21                       239                    56                    115
# 22                      2692                    91                   1353
# 23                      2534                    84                   1415
# 24                       284                    59                    165
# 25                       596                    49                    229
# 26                      9548                    70                   5075
# 27                      3362                    77                   1679
# 28                      2464                    77                   1614
# 29                     76244                    78                  39229
# 30                     15593                    56                   5779
# 31                       713                    66                    407
# 32                     40097                    61                  18695
# 33                     49642                    69                  25002
# 34                       872                    67                    441
# 35                     55740                    67                  25364
# 36                     79982                    80                  41438
# 37                     49946                    85                  21940
# 38                     13112                    75                   6794
# 39                      4221                    71                   1678
# 40                     12271                    76                   6935
# 41                      8968                    80                   4576
# 42                     62656                    73                  36006
# 43                      3745                    81                   2066
# 44                      4715                    64                   2041
# 45                      1172                    72                    662
# 46                      9978                    66                   5249
# 47                     10885                    76                   6170
# 48                     15913                    61                   6708
# 49                       166                    68                     65
# 50                      1039                    78                    418
# 51                       211                    58                    108
# 52                      6735                    83                   4481
# 53                      1628                    77                    958
# 54                     17146                    67                   6731
# 55                      2372                    74                    992
# 56                      3210                    89                   2014
#
#     ...  Cont_Number_Working  Con_FluVaccPerc_r  Lip_Number_Vaccinated  \
# 0   ...                56438               70.0                 111513
# 1   ...                 1634               69.0                   5986
# 2   ...                  939               77.0                    192
# 3   ...                  652               35.0                    351
# 4   ...                   13               77.0                     79
# 5   ...                   24               25.0                     35
# 6   ...                  544               67.0                   2381
# 7   ...                    0                NaN                     67
# 8   ...                   66               45.0                    253
# 9   ...                  644               77.0                   3348
# 10  ...                  115               32.0                     30
# 11  ...                  111               95.0                    399
# 12  ...                  143               94.0                    178
# 13  ...                   80               56.0                     64
# 14  ...                 2118               78.0                   2504
# 15  ...                  127               91.0                    326
# 16  ...                   27               85.0                    266
# 17  ...                    0                NaN                     51
# 18  ...                19613               59.0                  27310
# 19  ...                   88               35.0                    241
# 20  ...                  123               77.0                    711
# 21  ...                    4              100.0                     12
# 22  ...                  415               90.0                    559
# 23  ...                  184               93.0                    290
# 24  ...                    1                0.0                      2
# 25  ...                    1              100.0                     63
# 26  ...                  867               71.0                    463
# 27  ...                  129               97.0                    466
# 28  ...                   29               31.0                    162
# 29  ...                 5385               92.0                   9775
# 30  ...                 2570               61.0                   1197
# 31  ...                    0                NaN                     45
# 32  ...                 1512               81.0                   2733
# 33  ...                 2920               83.0                   3024
# 34  ...                   93               68.0                     38
# 35  ...                 1489               69.0                   6511
# 36  ...                 4711               86.0                  10382
# 37  ...                 1709               82.0                   8448
# 38  ...                 1349               72.0                   1424
# 39  ...                  561               75.0                    522
# 40  ...                  225               44.0                   1822
# 41  ...                  506               63.0                   1175
# 42  ...                  875               71.0                   7674
# 43  ...                  269               86.0                    528
# 44  ...                  174               50.0                    587
# 45  ...                   57               77.0                     97
# 46  ...                  103               70.0                   1055
# 47  ...                  304               89.0                   1325
# 48  ...                 1363               50.0                   1606
# 49  ...                   39               59.0                     22
# 50  ...                    0                NaN                    229
# 51  ...                    7               43.0                     12
# 52  ...                   67               96.0                    649
# 53  ...                    0                NaN                    159
# 54  ...                 1109               63.0                   2857
# 55  ...                   65               91.0                    541
# 56  ...                  285               80.0                    287
#
#     Lip_Number_Working  LIP_FluVaccPerc_r  StudVol_Number_Vaccinated  \
# 0               152019                 73                      69574
# 1                 8040                 74                       1668
# 2                  201                 96                         17
# 3                  578                 61                        784
# 4                   83                 95                         18
# 5                   51                 69                         24
# 6                 3803                 63                       1017
# 7                   89                 75                         33
# 8                  352                 72                         87
# 9                 4079                 82                       2249
# 10                  51                 59                          5
# 11                 531                 75                         34
# 12                 422                 42                        180
# 13                  83                 77                         21
# 14                3094                 81                        729
# 15                 352                 93                          0
# 16                 316                 84                        125
# 17                  55                 93                          0
# 18               35266                 77                      18804
# 19                 424                 57                        257
# 20                 918                 77                        249
# 21                  40                 30                          2
# 22                 592                 94                        164
# 23                 350                 83                        258
# 24                   5                 40                          0
# 25                  72                 88                          0
# 26                 978                 47                        528
# 27                 582                 80                        316
# 28                 226                 72                        109
# 29               13598                 72                       5204
# 30                1708                 70                        227
# 31                  67                 67                         16
# 32                6560                 42                       1746
# 33                5314                 57                       3676
# 34                  52                 73                         43
# 35                9221                 71                       4273
# 36               12850                 81                       7891
# 37                9311                 91                      10624
# 38                2094                 68                        613
# 39                 901                 58                        381
# 40                2388                 76                        436
# 41                1277                 92                       1098
# 42               11032                 70                       1377
# 43                 627                 84                        201
# 44                 738                 80                        286
# 45                 120                 81                         46
# 46                1242                 85                        222
# 47                1564                 85                        536
# 48                2659                 60                        662
# 49                  24                 92                          3
# 50                 239                 96                        164
# 51                  15                 80                          0
# 52                 771                 84                        380
# 53                 184                 86                        135
# 54                4828                 59                       1163
# 55                 706                 77                        171
# 56                 296                 97                        322
#
#     StudVol_Number_Working  StudVolFluVaccPerc_r  Met_2020Goal  Notes
# 0                    83980                  83.0            No    NaN
# 1                     1934                  86.0            No    NaN
# 2                       17                 100.0            No    NaN
# 3                     1182                  66.0            No    NaN
# 4                       33                  55.0            No    NaN
# 5                       38                  63.0            No    NaN
# 6                     1441                  71.0            No    NaN
# 7                       33                 100.0            No    NaN
# 8                      140                  62.0            No    NaN
# 9                     2358                  95.0            No    NaN
# 10                       6                  83.0            No    NaN
# 11                      34                 100.0            No    NaN
# 12                     364                  49.0            No    NaN
# 13                      34                  62.0            No    NaN
# 14                    1120                  65.0            No    NaN
# 15                       0                   NaN           Yes    NaN
# 16                     125                 100.0            No    NaN
# 17                       0                   NaN            No    NaN
# 18                   23737                  79.0            No    NaN
# 19                     453                  57.0            No    NaN
# 20                     306                  81.0            No    NaN
# 21                       2                 100.0            No    NaN
# 22                     184                  89.0           Yes    NaN
# 23                     263                  98.0            No    NaN
# 24                       0                   NaN            No    NaN
# 25                       0                   NaN            No    NaN
# 26                     660                  80.0            No    NaN
# 27                     331                  95.0            No    NaN
# 28                     141                  77.0            No    NaN
# 29                    6136                  85.0            No    NaN
# 30                     686                  33.0            No    NaN
# 31                      18                  89.0            No    NaN
# 32                    2693                  65.0            No    NaN
# 33                    4455                  83.0            No    NaN
# 34                      49                  88.0            No    NaN
# 35                    4684                  91.0            No    NaN
# 36                    8855                  89.0            No    NaN
# 37                   11016                  96.0            No    NaN
# 38                     765                  80.0            No    NaN
# 39                     478                  80.0            No    NaN
# 40                     513                  85.0            No    NaN
# 41                    1238                  89.0            No    NaN
# 42                    2020                  68.0            No    NaN
# 43                     202                 100.0            No    NaN
# 44                     400                  72.0            No    NaN
# 45                      51                  90.0            No    NaN
# 46                     283                  78.0            No    NaN
# 47                     602                  89.0            No    NaN
# 48                    1022                  65.0            No    NaN
# 49                       4                  75.0            No    NaN
# 50                     169                  97.0            No    NaN
# 51                       0                   NaN            No    NaN
# 52                     452                  84.0            No    NaN
# 53                     170                  79.0            No    NaN
# 54                    1559                  75.0            No    NaN
# 55                     188                  91.0            No    NaN
# 56                     336                  96.0            No    NaN
#
# [57 rows x 23 columns]

# %%
#### columns for this data

fluvaccine_df.columns
# Out:
# Index(['Influenza_Season', 'State', 'CDPH_HAI_HCP_FLU_VACCINATION', 'County',
#        'order_this_season', 'Number_Hospitals', 'HCP_Total_Number_Vaccinated',
#        'HCP_Total_Number_Working', 'AllHCP_FluVaccPerc_r',
#        'Emp_Number_Vaccinated', 'Emp_Number_Working', 'Emp_FluVaccPerc_r',
#        'Cont_Number_Vaccinated', 'Cont_Number_Working', 'Con_FluVaccPerc_r',
#        'Lip_Number_Vaccinated', 'Lip_Number_Working', 'LIP_FluVaccPerc_r',
#        'StudVol_Number_Vaccinated', 'StudVol_Number_Working',
#        'StudVolFluVaccPerc_r', 'Met_2020Goal', 'Notes'],
#       dtype='object')

# %%
fluvaccine_df['County']
# Out:
# 0     State of California
# 1                 Alameda
# 2                  Amador
# 3                   Butte
# 4               Calaveras
# 5                  Colusa
# 6            Contra Costa
# 7               Del Norte
# 8               El Dorado
# 9                  Fresno
# 10                  Glenn
# 11               Humboldt
# 12               Imperial
# 13                   Inyo
# 14                   Kern
# 15                  Kings
# 16                   Lake
# 17                 Lassen
# 18            Los Angeles
# 19                 Madera
# 20                  Marin
# 21               Mariposa
# 22              Mendocino
# 23                 Merced
# 24                  Modoc
# 25                   Mono
# 26               Monterey
# 27                   Napa
# 28                 Nevada
# 29                 Orange
# 30                 Placer
# 31                 Plumas
# 32              Riverside
# 33             Sacramento
# 34             San Benito
# 35         San Bernardino
# 36              San Diego
# 37          San Francisco
# 38            San Joaquin
# 39        San Luis Obispo
# 40              San Mateo
# 41          Santa Barbara
# 42            Santa Clara
# 43             Santa Cruz
# 44                 Shasta
# 45               Siskiyou
# 46                 Solano
# 47                 Sonoma
# 48             Stanislaus
# 49                 Sutter
# 50                 Tehama
# 51                Trinity
# 52                 Tulare
# 53               Tuolumne
# 54                Ventura
# 55                   Yolo
# 56                   Yuba
# Name: County, dtype: object

# %%
fluvaccine_df['Emp_Number_Vaccinated']
# Out:
# 0     489511
# 1      21050
# 2        306
# 3       2935
# 4        219
# 5        143
# 6      11653
# 7        269
# 8       1754
# 9      16181
# 10       166
# 11      1487
# 12      1540
# 13       305
# 14      8683
# 15      1189
# 16       871
# 17       256
# 18    127723
# 19      4174
# 20      4015
# 21       115
# 22      1353
# 23      1415
# 24       165
# 25       229
# 26      5075
# 27      1679
# 28      1614
# 29     39229
# 30      5779
# 31       407
# 32     18695
# 33     25002
# 34       441
# 35     25364
# 36     41438
# 37     21940
# 38      6794
# 39      1678
# 40      6935
# 41      4576
# 42     36006
# 43      2066
# 44      2041
# 45       662
# 46      5249
# 47      6170
# 48      6708
# 49        65
# 50       418
# 51       108
# 52      4481
# 53       958
# 54      6731
# 55       992
# 56      2014
# Name: Emp_Number_Vaccinated, dtype: int64
